# %% [markdown]
# # Recommendation Systems

# %% [markdown]
# Companies like Amazon(books, items), Netflix(movies), Google(News,Search), and Pandora/Spotify(music) leverage recommendation systems to help users discover new and relevant items (products, videos, jobs, music), creating a delightful user experience while driving incremental revenue.
#
# The need to build robust recommendation systems is extremely important given the huge demand for personalized content of modern consumers.

# %% [markdown]
# In this assignment, you will be applying your learning of recommendation systems in this Unit towards building the following four different types of recommendation systems:
#
# 1.   Global Recommendation Systems (Statistical)
# 2.   Content-based Recommendation Systems
# 3.   Collaborative Filtering (User-Item) Recommendation Systems
# 4.   Hybrid Recommendation Systems
#
# The focus of the mini-project here would be to build a movie recommendation system.

# %% [markdown]
# ## 1. Dataset Acquisition
#
# Following are the key descriptions of the datasets you will be using. The data used here has been compiled from various movie datasets like Netflix and IMDb.
#
# 1. __Filename: `movie_titles.csv`:__
#
#   - __`MovieID`__: MovieID does not correspond to actual Netflix movie ids or IMDB movie ids
#   - __`YearOfRelease`__: YearOfRelease can range from 1890 to 2005 and may correspond to the release of corresponding DVD, not necessarily its theaterical release
#   - __`Title`__: Title is the Netflix movie title and may not correspond to titles used on other sites. Titles are in English
#
#
# 2. __Combined User-Ratings Dataset Description - `combined_data.csv`:__
#
#   - The first line of the contains the movie id followed by a colon.
#   - Each subsequent line in the file corresponds to a rating from a customer and its date in the following format:
#
#     - MovieIDs range from 1 to 17770 sequentially.
#     - CustomerIDs range from 1 to 2649429, with gaps. There are 480189 users.
#     - Ratings are on a five star (integral) scale from 1 to 5.
#     - Dates have the format YYYY-MM-DD.
#
#
# 3. __Filename: `movies_metadata.csv`__
#
# The main Movies Metadata file. Contains information on 45,000 movies featured in the Full MovieLens dataset. Features include posters, backdrops, budget, revenue, release dates, languages, production countries and companies.

# %% [markdown]
# ## 2: Import Necessary Dependencies
#
# We will be leveraging __`keras`__ on top of __`tensorflow`__ for building some of the collaborative filtering and hybrid models. There are compatibility issues with handling sparse layers with dense layers till now in TensorFlow 2 hence we are leveraging native Keras but in the long run once this issue is resolved we can leverage __`tf.keras`__ with minimal code updates.

# %%
# filter out unncessary warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# To store\load the data
import pandas as pd

# To do linear algebra
import numpy as np

# To create plots
import matplotlib.pyplot as plt
import seaborn as sns


# To compute similarities between vectors
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# data load progress bars
from tqdm import tqdm

from collections import deque

# To create deep learning models
import tensorflow as tf
import keras
from keras.layers import Input, Embedding, Reshape, Dot, Concatenate, Dense, Dropout
from keras.models import Model

# To stack sparse matrices
from scipy.sparse import vstack

# %%
# remove unnecessary TF logs
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
# check keras and TF version used
print('TF Version:', tf.__version__)
print('Keras Version:', keras.__version__)
# TF Version: 1.15.0
# Keras Version: 2.2.5
# Out:
# TF Version: 2.12.0
# Keras Version: 2.12.0

# %% [markdown]
# Let's start loading data that will be used for building the recommendation systems

# %% [markdown]
# # 3. Load Datasets

# %% [markdown]
# ## 3.1: Load Movie Metadata Datasets
#
# First, we will load the movie_titles.csv data from the Netflix prize data source

# %%
# Reading csv file direction and print row

import csv
import zipfile

target_zip_file_path = './data/movie_titles.csv.zip'

def list_files_in_zip(zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
        file_list = zip_file.namelist()
        for file_name in file_list:
            print(f'filename in zipfile: {file_name}')
            print('movie_titles.csv' == file_name )

list_files_in_zip(target_zip_file_path)

# def read_zipped_csv(zip_file_path, csv_file_name):
#     with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
#         with zip_file.open(csv_file_name) as csv_file:
#             csv_reader = csv.reader(csv_file)
#             for row in csv_reader:
#                 # Process each row of the CSV data
#                 print(row)

# print only raw data
def read_zipped_csv(zip_file_path, csv_file_name):
    with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
        with zip_file.open(csv_file_name) as csv_file:
            print(f'in zip file ---: {csv_file}')
            for row in csv_file:
                print(row)
            # with open(csv_file_name, 'r') as file:
            #     for line in file:
            #         # Process each line here
            #         print(line)



read_zipped_csv('./data/movie_titles.csv.zip', 'movie_titles.csv')
# Out:
# filename in zipfile: movie_titles.csv
# True
# in zip file ---: <zipfile.ZipExtFile name='movie_titles.csv' mode='r' compress_type=deflate>
# b'1,2003,Dinosaur Planet\n'
# b'2,2004,Isle of Man TT 2004 Review\n'
# b'3,1997,Character\n'
# b"4,1994,Paula Abdul's Get Up & Dance\n"
# b'5,2004,The Rise and Fall of ECW\n'
# b'6,1997,Sick\n'
# b'7,1992,8 Man\n'
# b'8,2004,What the #$*! Do We Know!?\n'
# b"9,1991,Class of Nuke 'Em High 2\n"
# b'10,2001,Fighter\n'
# b'11,1999,Full Frame: Documentary Shorts\n'
# b'12,1947,My Favorite Brunette\n'
# b'13,2003,Lord of the Rings: The Return of the King: Extended Edition: Bonus Material\n'
# b'14,1982,Nature: Antarctica\n'
# b'15,1988,Neil Diamond: Greatest Hits Live\n'
# b'16,1996,Screamers\n'
# b'17,2005,7 Seconds\n'
# b'18,1994,Immortal Beloved\n'
# b"19,2000,By Dawn's Early Light\n"
# b'20,1972,Seeta Aur Geeta\n'
# b'21,2002,Strange Relations\n'
# b'22,2000,Chump Change\n'
# b"23,2001,Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo\n"
# b'24,1981,My Bloody Valentine\n'
# b'25,1997,Inspector Morse 31: Death Is Now My Neighbour\n'
# b'26,2004,Never Die Alone\n'
# b"27,1962,Sesame Street: Elmo's World: The Street We Live On\n"
# b'28,2002,Lilo and Stitch\n'
# b'29,2001,Boycott\n'
# b"30,2003,Something's Gotta Give\n"
# b'31,1999,Classic Albums: Meat Loaf: Bat Out of Hell\n'
# b"32,2004,ABC Primetime: Mel Gibson's The Passion of the Christ\n"
# b'33,2000,Aqua Teen Hunger Force: Vol. 1\n'
# b"34,2003,Ashtanga Yoga: Beginner's Practice with Nicki Doane\n"
# b'35,2000,Ferngully 2: The Magical Rescue\n'
# b'36,1992,Lady Chatterley\n'
# b"37,1973,Zatoichi's Conspiracy\n"
# b'38,2003,Daydream Obsession\n'
# b'39,2000,Love Reinvented\n'
# b'40,2004,Pitcher and the Pin-Up\n'
# b'41,2000,Horror Vision\n'
# b'42,2002,Searching for Paradise\n'
# b'43,2000,Silent Service\n'
# b'44,1996,Spitfire Grill\n'
# b'45,1999,The Love Letter\n'
# b'46,1964,Rudolph the Red-Nosed Reindeer\n'
# b'47,1952,The Bad and the Beautiful\n'
# b'48,2001,Justice League\n'
# b'49,2003,Devo: The Complete Truth About De-evolution\n'
# b'50,1941,A Yank in the R.A.F.\n'
# b'51,2002,Jonah: A VeggieTales Movie: Bonus Material\n'
# b'52,2002,The Weather Underground\n'
# b'53,2003,The Bonesetter\n'
# b"54,1952,We're Not Married\n"
# b'55,1995,Jade\n'
# b'56,2004,Carandiru\n'
# b'57,1995,Richard III\n'
# b'58,1996,Dragonheart\n'
# b'59,2003,Sex and the Beauties\n'
# b'60,1969,The Libertine\n'
# b'61,1999,Ricky Martin: One Night Only\n'
# b"62,1991,Ken Burns' America: Empire of the Air\n"
# b'63,1943,Crash Dive\n'
# b'64,2001,Outside the Law\n'
# b'65,2000,Lost in the Pershing Point Hotel\n'
# b'66,1989,Barbarian Queen 2\n'
# b'67,1997,Vampire Journals\n'
# b'68,2004,Invader Zim\n'
# b'69,2003,WWE: Armageddon 2003\n'
# b'70,1999,Tai Chi: The 24 Forms\n'
# b'71,1995,Maya Lin: A Strong Clear Vision\n'
# b'72,1974,At Home Among Strangers, A Stranger Among His Own\n'
# b'73,1954,Davy Crockett: 50th Anniversary Double Feature\n'
# b'74,1999,6ixtynin9\n'
# b'75,1997,Grind\n'
# b'76,1952,I Love Lucy: Season 2\n'
# b'77,1995,Congo\n'
# b'78,1996,Jingle All the Way\n'
# b'79,1956,The Killing\n'
# b'80,1979,Winter Kills\n'
# b'81,1991,Antarctica: IMAX\n'
# b'82,1951,The Frogmen\n'
# b'83,1983,Silkwood\n'
# b'84,2002,The Powerpuff Girls Movie\n'
# b'85,2005,Elfen Lied\n'
# b'86,1996,Iron Monkey 2\n'
# b'87,2002,Louder Than Bombs\n'
# b'88,1998,Record of Lodoss War: Chronicles of the Heroic Knight\n'
# b'89,2000,Chain of Command\n'
# b'90,1951,The Lemon Drop Kid\n'
# b'91,2005,WWE: Royal Rumble 2005\n'
# b"92,2002,ECW: Cyberslam '99\n"
# b'93,2004,They Came Back\n'
# b'94,2000,G3: Live in Concert\n'
# b'95,1985,Dona Herlinda and Her Son\n'
# b'96,2000,Inside the Space Station\n'
# b'97,2002,Mostly Martha\n'
# b'98,1965,The Battle of Algiers: Bonus Material\n'
# b'99,1989,A Fishy Story\n'
# b'100,1993,Sam the Iron Bridge\n'
# b'101,1997,Complete Shamanic Princess\n'
# b'102,2004,Notre Musique\n'
# b'103,1976,Sanford and Son: Season 6\n'
# b'104,1965,The Great Race\n'
# b'105,2002,Obsessed\n'
# b'106,2004,Stevie Ray Vaughan and Double Trouble: Live at Montreux 1982 & 1985\n'
# b'107,2000,Magnolia: Bonus Material\n'
# b'108,2004,Spartan\n'
# b'109,1996,No Way Back\n'
# b'110,1989,Scandal\n'
# b'111,2003,Duplex (Widescreen)\n'
# b'112,1993,The Eye of Vichy\n'
# b"113,2000,Bruce Lee: A Warrior's Journey\n"
# b'114,1989,Dominion Tank Police Part 1 & 2\n'
# b'115,1973,Lord Peter Wimsey: Murder Must Advertise\n'
# b'116,2004,Bear Cub\n'
# b'117,1957,Silk Stockings\n'
# b'118,1985,Rambo: First Blood Part II\n'
# b'119,1999,Travel the World by Train: Africa\n'
# b'120,2004,Plain Dirty\n'
# b'121,2003,Beyonce: Live at Wembley\n'
# b'122,2002,Cube 2: Hypercube\n'
# b'123,2000,Chain of Fools\n'
# b'124,2000,Cold Blooded\n'
# b'125,1981,Nighthawks\n'
# b'126,2003,Vampire Effect (aka Twins Effect)\n'
# b'127,1987,Fatal Beauty\n'
# b'128,1985,Mr. Vampire\n'
# b'129,2003,Darkwolf\n'
# b'130,1999,Drowning on Dry Land\n'
# b'131,2002,Arachnid\n'
# b'132,1981,Lucio Fulci: The Beyond\n'
# b'133,2003,Viva La Bam: Season 1\n'
# b'134,1996,Spirit Lost\n'
# b'135,1998,GTO: Great Teacher Onizuka: Set 2\n'
# b'136,1927,Cat and the Canary\n'
# b'137,1998,Naked Lies\n'
# b'138,1995,Star Trek: Voyager: Season 1\n'
# b'139,2001,Allergies: A Natural Approach\n'
# b'140,1993,Lost in the Wild\n'
# b'141,2004,Goddess of Mercy\n'
# b'142,2000,The Tricky Master\n'
# b'143,1997,The Game\n'
# b'144,2000,Deepak Chopra: The Way of the Wizard & Alchemy\n'
# b'145,1978,Get Out Your Handkerchiefs\n'
# b'146,1988,Cannibal Women in the Avocado Jungle of Death\n'
# b'147,1992,Where Sleeping Dogs Lie\n'
# b'148,2001,Sweet November\n'
# b'149,2005,The Edward R. Murrow Collection\n'
# b'150,2001,Firetrap\n'
# b'151,2005,Sleepover Nightmare\n'
# b'152,1995,A Little Princess\n'
# b'153,2002,MTV Yoga\n'
# b'154,2000,Demon Warrior Koji\n'
# b'155,1975,The Strongest Man in the World\n'
# b'156,1992,Husbands and Wives\n'
# b'157,2004,Laird: White Knuckle Extreme\n'
# b'158,2004,A Killer Within\n'
# b'159,1971,Gentlemen of Fortune\n'
# b'160,2000,Gormenghast\n'
# b'161,1939,Ninotchka\n'
# b'162,1968,John Cleese on How to Irritate People\n'
# b'163,2002,MTV: Making the Band 2: Best of Season 1\n'
# b'164,2003,One Last Dance\n'
# b'165,1982,Richard Pryor: Live on the Sunset Strip\n'
# b'166,1980,Fame\n'
# b'167,2004,The Chorus\n'
# b'168,1983,Smokey and the Bandit Part 3\n'
# b'169,2004,Cartoon Network Halloween: 9 Creepy Cartoon Capers\n'
# b'170,1972,Tomorrow\n'
# b'171,1957,Funny Face\n'
# b'172,2003,Jack\n'
# b"173,1968,The Devil's Brigade\n"
# b'174,1968,Adam-12: Season 1\n'
# b'175,1992,Reservoir Dogs\n'
# b'176,2004,The History Channel Presents: Troy: Unearthing the Legend\n'
# b'177,2002,Pressure\n'
# b'178,1996,Regular Guys\n'
# b'179,2003,Bollywood Bound\n'
# b'180,2002,Scratch\n'
# b'181,2004,The Last Shot\n'
# b'182,2001,Moby: Play\n'
# b'183,2005,IFilm: Deranged\n'
# b'184,2004,Billy Blanks: Tae Bo: Cardio Circuit 1\n'
# b'185,1985,Missing in Action 2: The Beginning / Missing in Action 3: Braddock\n'
# b'186,1950,Panic in the Streets\n'
# b'187,2002,Death to Smoochy\n'
# b'188,2005,Dead Birds\n'
# b'189,1982,Airplane II: The Sequel\n'
# b'190,1989,Blood and Sand\n'
# b'191,2003,X2: X-Men United\n'
# b'192,2003,The SoulTaker\n'
# b'193,2005,Marilyn Manson: Fear of a Satanic Planet\n'
# b'194,1996,Arliss: The Best of Arliss\n'
# b'195,2004,Chasing Freedom\n'
# b'196,1992,Peter Tosh: Stepping Razor: Red X\n'
# b'197,2004,Taking Lives\n'
# b'198,1997,Gupt\n'
# b'199,1978,The Deer Hunter\n'
# b'200,1964,The Fall of the Roman Empire\n'
# b'201,2001,Home Movie\n'
# b"202,2001,Ruby's Bucket of Blood\n"
# b'203,1997,Sports Illustrated Swimsuit Edition: 1997\n'
# b'204,2002,Venus Boyz\n'
# b'205,2004,Troy: Bonus Material\n'
# b'206,2004,Unconstitutional: The War on Our Civil Liberties\n'
# b'207,2001,Denise Austin: Ultimate Fat Burner\n'
# b'208,1947,The Three Stooges: Sing a Song of Six Pants\n'
# b'209,1996,Star Trek: Deep Space Nine: Season 5\n'
# b'210,2001,Onmyoji\n'
# b'211,2004,The Agronomist\n'
# b'212,1982,Querelle\n'
# b'213,2001,Dinner Rush\n'
# b'214,2002,Read-Along: Beauty and the Beast\n'
# b"215,1998,That '70s Show: Season 1\n"
# b'216,2000,Impostor\n'
# b'217,1988,Cherry 2000\n'
# b'218,1983,Triumph: Live at the US Festival\n'
# b'219,1995,Neon Bible\n'
# b'220,1983,Winston Churchill: The Wilderness Years\n'
# b'221,2005,Voyage to the Planets and Beyond\n'
# b'222,1998,Yellow\n'
# b"223,2003,Chappelle's Show: Season 1\n"
# b'224,1999,Midsomer Murders: Blood Will Out\n'
# b'225,2004,The Cookout\n'
# b'226,1996,Henry: Portrait of a Serial Killer 2\n'
# b'227,2001,The Carol Burnett Show: Show Stoppers\n'
# b'228,1979,Butch and Sundance: The Early Days\n'
# b'229,2003,Peter Gabriel: Growing Up Live\n'
# b'230,1987,Unsolved Mysteries: Psychics\n'
# b'231,2002,Marooned in Iraq\n'
# b'232,1989,Gross Anatomy\n'
# b"233,1971,Chato's Land\n"
# b'234,1921,Animation Legend: Winsor McCay\n'
# b'235,1996,Unhook the Stars\n'
# b'236,1998,Cartoon Crazys Sci-Fi\n'
# b'237,1918,Broken Blossoms\n'
# b'238,1976,Led Zeppelin: The Song Remains the Same\n'
# b'239,2004,Winnie the Pooh: Springtime with Roo\n'
# b'240,1942,Woman of the Year\n'
# b'241,1959,North by Northwest\n'
# b'242,1995,Neon Genesis Evangelion: The End of Evangelion\n'
# b'243,1962,Pressure Point\n'
# b'244,2004,Stellvia\n'
# b'245,2002,Road Dogz\n'
# b'246,1968,The Boston Strangler\n'
# b'247,1994,Oleanna\n'
# b"248,2001,Michael Moore's The Awful Truth: Season 2\n"
# b'249,1958,The Hunters\n'
# b'250,1966,Cast a Giant Shadow\n'
# b"251,2000,Midsomer Murders: Strangler's Wood\n"
# b'252,2002,Stuart Little 2\n'
# b'253,1935,A Night at the Opera\n'
# b'254,2003,Westender\n'
# b'255,2001,The Hunchback of Notre Dame II\n'
# b'256,2000,Ghost Dog: The Way of the Samurai\n'
# b"257,1973,Charlotte's Web\n"
# b'258,1999,Mann\n'
# b'259,2004,Animal\n'
# b'260,1967,Marat / Sade\n'
# b'261,1948,The Big Clock\n'
# b'262,1974,Herbie Rides Again\n'
# b'263,2001,Dragon Ball: Tournament Saga\n'
# b'264,2002,Angelina Ballerina: Lights, Camera, Action!\n'
# b'265,2002,The Jeff Corwin Experience: Costa Rica and the Amazon\n'
# b'266,2000,Saudade Do Futuro\n'
# b'267,1994,Touched by an Angel: Season 1\n'
# b'268,1980,The Final Countdown\n'
# b'269,1989,Parenthood\n'
# b'270,2001,Sex and the City: Season 4\n'
# b'271,1943,Saludos Amigos\n'
# b'272,1973,Female Yakuza Tale\n'
# b'273,2004,Taxi\n'
# b'274,2002,Crazy as Hell\n'
# b'275,2002,Evelyn\n'
# b'276,1998,Cold Harvest\n'
# b'277,2003,Enigma: MCMXC A.D\n'
# b'278,1990,100 Days Before the Command\n'
# b'279,1984,Micki and Maude\n'
# b'280,1998,Sarah Brightman: In Concert\n'
# b'281,1993,The Legend\n'
# b'282,2003,Blue Seed: Beyond\n'
# b'283,1996,If These Walls Could Talk\n'
# b'284,2005,Sasquatch Hunters\n'
# b"285,1997,The Devil's Own\n"
# b'286,1966,Thunderbirds Are Go\n'
# b'287,1994,Luther Vandross: Always and Forever: An Evening of Songs\n'
# b'288,2004,Saturday Night Live: The Best of Chris Kattan\n'
# b'289,1998,The Avengers\n'
# b'290,2004,Harold and Kumar Go to White Castle\n'
# b'291,2000,Chained Heat 3: Hell Mountain\n'
# b'292,2005,Saturday Night Live: The Best of Gilda Radner\n'
# b'293,2003,Lennon Legend: The Very Best of John Lennon\n'
# b'294,2002,Oasis\n'
# b'295,1995,Ace Ventura: When Nature Calls\n'
# b'296,2000,In His Life: The John Lennon Story\n'
# b'297,2003,The Hebrew Hammer\n'
# b'298,2002,Crunch: Pick Your Spot Pilates\n'
# b"299,2001,Bridget Jones's Diary\n"
# b'300,1997,Option Zero\n'
# b'301,2003,Hard Ground\n'
# b'302,2001,The Isle\n'
# b'303,1959,Les Liaisons Dangereuses\n'
# b'304,1997,King of the Hill: Season 1\n'
# b'305,1996,Jack\n'
# b'306,2005,Sesame Street: Sing Yourself Silly!\n'
# b'307,2002,Godsmack: Smack This!\n'
# b'308,1974,The Legend of the 7 Golden Vampires/7 Brothers of Dracula\n'
# b'309,1975,The Day of the Locust\n'
# b'310,2000,Leila\n'
# b'311,1994,Ed Wood\n'
# b'312,2000,High Fidelity\n'
# b'313,2000,Pay It Forward\n'
# b'314,1985,Saturday Night Live: The Best of Jon Lovitz\n'
# b'315,1964,Combat! Season 3: Operation 2\n'
# b'316,1999,Futurama: Monster Robot Maniac Fun Collection\n'
# b'317,1997,Mandela and de Klerk\n'
# b'318,1994,Beyond Suspicion\n'
# b'319,1987,Straight to Hell\n'
# b'320,1997,Eat Your Heart Out\n'
# b'321,2004,Ju-Rei: The Uncanny\n'
# b'322,1974,Flesh Gordon\n'
# b'323,1999,Modern Vampires\n'
# b"324,1994,Mother's Boys\n"
# b'325,2004,Ghosts of Rwanda: Frontline\n'
# b'326,1937,The Plainsman\n'
# b'327,1997,Storefront Hitchcock\n'
# b'328,2002,Deftones: Live in Hawaii\n'
# b'329,1999,Dogma\n'
# b'330,1998,Wild Things\n'
# b'331,1997,Chasing Amy\n'
# b'332,2002,They Crawl\n'
# b'333,2003,Mail Call: The Best of Season 2\n'
# b'334,2005,The Pacifier\n'
# b'335,1981,Fear No Evil\n'
# b'336,1978,The Driver\n'
# b'337,1983,Star 80\n'
# b'338,1942,The Three Stooges: Three Smart Saps\n'
# b'339,1968,Rolling Stones: Rock and Roll Circus\n'
# b'340,1998,Midnight: 2000 Seen By...\n'
# b'341,2004,Tremors 4: The Legend Begins\n'
# b'342,2001,Noir\n'
# b'343,2000,French and Saunders: Live\n'
# b'344,1967,The Taming of the Shrew\n'
# b'345,1998,Star Trek: Voyager: Season 5\n'
# b'346,2005,Up and Down\n'
# b'347,1989,Iceman Cometh\n'
# b'348,1988,The Last Temptation of Christ\n'
# b'349,1978,The Swarm\n'
# b'350,1993,Dr. Quinn, Medicine Woman: Season 3\n'
# b'351,1969,Guns of the Magnificent Seven\n'
# b'352,1997,Pick a Card\n'
# b'353,2002,Life or Something Like It\n'
# b'354,1981,Sadomania\n'
# b'355,1973,Sinful Nuns of St. Valentine\n'
# b'356,2005,Look at Me\n'
# b'357,2003,House of Sand and Fog\n'
# b'358,1979,The Onion Field\n'
# b'359,2003,Absolutely Fabulous: Series 5\n'
# b'360,1999,Lies\n'
# b'361,2004,The Phantom of the Opera: Special Edition\n'
# b'362,2000,The Flintstones in Viva Rock Vegas\n'
# b'363,2002,Stark Raving Mad\n'
# b'364,2004,Billy Blanks: Tae Bo: Contact 2\n'
# b'365,1989,R.E.M.: Tourfilm\n'
# b'366,2004,Still, We Believe: The Boston Red Sox Movie\n'
# b'367,2003,Spun\n'
# b'368,1986,The Best of Designing Women\n'
# b'369,2000,Playing Mona Lisa\n'
# b'370,1918,Chaplin\n'
# b'371,1966,The Trouble with Angels\n'
# b'372,1998,Jeans\n'
# b'373,2000,Third World Cop\n'
# b'374,1976,The Little Girl Who Lives Down the Lane\n'
# b'375,2003,Nine Dead Gay Guys\n'
# b'376,2001,Genesis: The Way We Walk: Live in Concert\n'
# b'377,1979,Dick Francis: The Racing Game\n'
# b'378,2003,Party Monster\n'
# b'379,1996,Crash Dive\n'
# b'380,1992,Live Wire\n'
# b'381,1991,Out for Justice\n'
# b'382,2004,Buried in the Sand: The Deception of America\n'
# b'383,2001,Hit Team\n'
# b'384,1986,Crossroads\n'
# b'385,2002,The Santa Clause 2\n'
# b'386,1994,Princess Caraboo\n'
# b"387,1984,Bizet's Carmen\n"
# b'388,1990,Body Chemistry\n'
# b'389,2002,Steal\n'
# b'390,1981,The Fan\n'
# b'391,1967,The Monkees: Season 2\n'
# b"392,1993,Danielle Steel's Heartbeat\n"
# b'393,1998,The Replacement Killers\n'
# b'394,1916,20,000 Leagues Under the Sea\n'
# b'395,1935,Captain Blood\n'
# b'396,2001,Arjuna: Complete Collection\n'
# b'397,1946,A Night in Casablanca\n'
# b'398,1976,In the Realm of the Senses\n'
# b'399,2001,Fangs\n'
# b'400,1970,Rio Lobo\n'
# b'401,1989,Halloween 5: The Revenge of Michael Myers\n'
# b'402,1999,Pan Tadeusz\n'
# b'403,2000,Substitute 4: Failure is Not an Option\n'
# b'404,2001,The Shaft\n'
# b'405,1987,Wings of Desire\n'
# b'406,2005,Hostage\n'
# b'407,1972,The Abductors\n'
# b'408,1990,Nightbreed\n'
# b'409,1966,Godzilla vs. The Sea Monster\n'
# b'410,1998,Frank Lloyd Wright\n'
# b'411,1999,Vendetta\n'
# b'412,1999,Jay Jay the Jet Plane: Adventures in Learning\n'
# b'413,2002,Igby Goes Down\n'
# b'414,1999,Girl\n'
# b'415,2002,Reign in Darkness\n'
# b'416,2003,Elephant\n'
# b'417,1986,Transformers: Season 3: Part 1\n'
# b'418,2004,The Deal\n'
# b'419,2005,George Lopez: Why You Crying?\n'
# b'420,1999,Saturday Night Live: The Best of Dana Carvey\n'
# b"421,2003,Agatha Christie's Poirot: Sad Cypress\n"
# b'422,1964,The Unsinkable Molly Brown\n'
# b'423,1963,My Favorite Martian #1\n'
# b'424,1998,Happiness\n'
# b'425,2000,The 10th Kingdom\n'
# b"426,2001,Recess: School's Out\n"
# b'427,1990,Graveyard Shift\n'
# b"428,2004,Barney: Barney's Colorful World: Live\n"
# b'429,1997,Zeus and Roxanne\n'
# b'430,2002,Chobits\n'
# b'431,2002,Millennium Actress\n'
# b'432,1996,Les Miserables in Concert\n'
# b'433,1993,Untamed Heart\n'
# b"434,2004,Extreme Engineering: Tokyo's Sky City\n"
# b'435,1996,Love Can Seriously Damage Your Health\n'
# b'436,1985,Girls Just Want to Have Fun\n'
# b'437,2005,Beyblade: Fierce Battle\n'
# b'438,1997,Bean: The Movie\n'
# b'439,1961,Town Without Pity\n'
# b'440,2003,Just 4 Kicks\n'
# b'441,1968,Dark Shadows: Vol. 9\n'
# b'442,1988,Mississippi Burning\n'
# b'443,2002,Rabbit-Proof Fence\n'
# b'444,2001,The Inner Tour\n'
# b'445,1996,Michael Collins\n'
# b'446,1995,The Underneath\n'
# b'447,1986,The Making of Fanny and Alexander\n'
# b'448,2001,Oswald: Welcome to the Big City!\n'
# b'449,2003,Jimmy Buffett: MiniMatinee #1\n'
# b"450,2000,Isaac Stern: Life's Virtuoso\n"
# b'451,1993,Batman the Animated Series: Vol. 3\n'
# b'452,2002,Scorched\n'
# b'453,1992,Simple Men\n'
# b'454,1995,Xena: Warrior Princess: Season 3\n'
# b'455,1999,Cardcaptor Sakura: The Movie\n'
# b'456,1996,Emma (Miniseries)\n'
# b'457,2004,Kill Bill: Vol. 2\n'
# b'458,2001,Blast\n'
# b'459,1996,Basquiat\n'
# b'460,1971,Pink Narcissus\n'
# b'461,2000,Nightwalker #1: Midnight Detective\n'
# b'462,2005,Classic Cartoon Favorites: Starring Donald\n'
# b'463,1962,The Twilight Zone: Vol. 12\n'
# b'464,1987,The Return of Ruben Blades\n'
# b'465,1995,Coolie No.1\n'
# b'466,1990,Doogie Howser, M.D.: Season 2\n'
# b'467,1941,Topper Returns\n'
# b'468,2003,The Matrix: Revolutions\n'
# b'469,1998,First Night of My Life: 2000 Seen By...\n'
# b'470,2001,Beneath Loch Ness\n'
# b'471,1931,City Lights\n'
# b'472,1998,Mr. Jealousy\n'
# b'473,1997,Princess Mononoke\n'
# b'474,1998,Legend of 1900\n'
# b'475,1993,Surf Ninjas\n'
# b"476,2004,VeggieTales Classics: Where's God When I'm Scared?\n"
# b'477,1990,George Carlin: Personal Favorites\n'
# b'478,1962,The Beverly Hillbillies\n'
# b'479,1988,George Carlin: What Am I Doing in New Jersey?\n'
# b'480,1997,Flypaper\n'
# b'481,2002,Building the Great Pyramid\n'
# b'482,2002,Frida\n'
# b'483,2001,Rush Hour 2\n'
# b"484,1992,Danielle Steel's Jewels\n"
# b"485,1967,The Avengers '67\n"
# b'486,1959,Journey to the Center of the Earth\n'
# b'487,1968,Doctor Who: Lost in Time: The Patrick Troughton Years\n'
# b'488,2001,His Secret Life\n'
# b'489,1998,Return to Paradise\n'
# b'490,1999,The Passion of Ayn Rand\n'
# b'491,1966,Torn Curtain\n'
# b'492,1984,Mrs. Soffel\n'
# b'493,1972,The Giallo Collection: Who Saw Her Die?\n'
# b"494,1983,Monty Python's The Meaning of Life: Special Edition\n"
# b'495,2000,Mission Kashmir\n'
# b'496,2004,Primus: Hallucino-Genetics Live 2004\n'
# b"497,2003,Broadway's Lost Treasures\n"
# b'498,1989,Glory: Bonus Material\n'
# b'499,2000,Under Suspicion\n'
# b'500,2002,Mail Call: The Best of Season 1\n'
# b'501,1975,Three Days of the Condor\n'
# b'502,2003,Mitch Hedberg: Mitch All Together\n'
# b'503,2005,Max and Ruby: Springtime for Max and Ruby\n'
# b'504,1964,The Twilight Zone: Vol. 27\n'
# b'505,1997,A Thousand Acres\n'
# b"506,1976,Blank Generation / Dancin' Barefoot\n"
# b'507,1966,Nevada Smith\n'
# b'508,1979,Saint Jack\n'
# b'509,2004,The Volcano Disaster\n'
# b"510,2004,Blue's Clues: Blue's Room: It's Hug Day\n"
# b'511,2002,Avenging Angelo\n'
# b'512,2000,Bubblegum Crisis: Hurricane Live!\n'
# b'513,1995,Butterfly Kiss\n'
# b'514,2000,Santana: Supernatural Live\n'
# b'515,2005,Avia Vampire Hunter\n'
# b'516,2001,Monsoon Wedding\n'
# b'517,2001,Two Can Play That Game\n'
# b'518,1969,The Prime of Miss Jean Brodie\n'
# b'519,1979,From Mao to Mozart: Isaac Stern in China\n'
# b"520,2004,E's Otherwise\n"
# b'521,1927,Presenting Felix the Cat\n'
# b'522,1999,Love Songs\n'
# b'523,1969,My Side of the Mountain\n'
# b'524,1999,Mumford\n'
# b'525,1999,The Last Seduction II\n'
# b'526,1994,Angie\n'
# b'527,1985,Barbarian Queen\n'
# b"528,2005,The Hitchhiker's Guide to the Galaxy\n"
# b'529,1998,Summer of the Monkeys\n'
# b'530,1987,Return to Horror High\n'
# b"531,1996,You're Invited to Mary-Kate and Ashley's Vacation Parties\n"
# b'532,1988,Young Einstein\n'
# b'533,1991,Drop Dead Fred\n'
# b'534,2000,With a Friend Like Harry\n'
# b'535,1960,The Alamo\n'
# b'536,2001,Sol Goode\n'
# b'537,1991,Here is Greenwood\n'
# b'538,2003,A Crime of Passion\n'
# b'539,1987,Rumpole of the Bailey: Series 4\n'
# b'540,2003,Ghosts of the Abyss: Bonus Material\n'
# b'541,1998,King Cobra\n'
# b'542,1997,The Blackout\n'
# b'543,1999,Roughnecks: The Starship Troopers Chronicles: The Pluto Campaign\n'
# b'544,1987,Maurice: Bonus Material\n'
# b'545,2002,Bob the Builder: The Big Game\n'
# b'546,2005,The Strip Game\n'
# b'547,1992,Kuffs\n'
# b'548,1991,Hudson Hawk\n'
# b'549,1955,Rage at Dawn\n'
# b'550,1995,First Knight\n'
# b'551,1994,The Santa Clause\n'
# b'552,1994,Radioland Murders\n'
# b'553,1995,Rangeela\n'
# b'554,1972,Solaris\n'
# b'555,1996,Cadfael: A Morbid Taste for Bones\n'
# b'556,1999,New Waterford Girl\n'
# b'557,1991,Liebestraum\n'
# b'558,1994,Fantastic Four\n'
# b'559,1940,Rebecca: Bonus Material\n'
# b'560,2003,Star Trek: Enterprise: Season 3\n'
# b'561,1963,High and Low\n'
# b'562,2002,Bloody Mallory\n'
# b'563,2001,Jimmy Neutron: Boy Genius\n'
# b'564,1990,Predator 2\n'
# b'565,2002,Tom Petty and the Heartbreakers: Live at the Olympic: The Last DJ\n'
# b'566,1996,Bullet\n'
# b'567,2003,Dunsmore\n'
# b'568,1999,Knights of Ramune\n'
# b'569,1979,The In-Laws\n'
# b'570,2000,The Visit\n'
# b'571,1999,American Beauty\n'
# b'572,1962,The Masque of the Red Death / The Premature Burial\n'
# b'573,1983,Winners & Sinners\n'
# b'574,1960,Strangers When We Meet\n'
# b'575,1994,Highlander: Season 4\n'
# b'576,2000,Popular: Season 2\n'
# b'577,1961,The Twilight Zone: Vol. 36\n'
# b'578,1963,The Terror\n'
# b'579,1973,The Autobiography of Miss Jane Pittman\n'
# b'580,1971,THX 1138: Special Edition\n'
# b'581,1993,Black Jack: The Movie\n'
# b'582,1986,Jo Jo Dancer, Your Life is Calling\n'
# b'583,1959,Third Man on the Mountain\n'
# b'584,1998,The Curve\n'
# b'585,1995,My Family\n'
# b'586,1995,Shanghai Triad\n'
# b'587,1983,The Scarlet and the Black\n'
# b'588,1990,Blue Planet: IMAX\n'
# b'589,2000,Northanger Abbey\n'
# b'590,2001,Michael McDonald: A Gathering of Friends\n'
# b'591,2003,Particles of Truth\n'
# b'592,1974,House of Whipcord\n'
# b'593,2000,Baby Genius: Mozart and Friends\n'
# b'594,2002,By Hook or By Crook\n'
# b'595,2001,Monarch of the Glen: Series 2\n'
# b'596,1999,Alice in Wonderland (TV Version)\n'
# b'597,1977,The Brady Bunch Variety Hour\n'
# b'598,1973,Bobby Darin: Mack is Back\n'
# b'599,1989,Sea of Love\n'
# b"600,1966,What's Up, Tiger Lily?\n"
# b'601,1992,The Smiths: The Complete Picture\n'
# b'602,2000,Tokyo Raiders\n'
# b'603,1997,Burn Up Excess: Vol. 1: To Serve and Protect\n'
# b"604,2005,Walt Disney's Timeless Tales: Vol. 2\n"
# b'605,2000,The Secrets of the Dead Sea Scrolls\n'
# b'606,1968,Quatermass and the Pit\n'
# b'607,1994,Speed\n'
# b'608,1970,The Lickerish Quartet\n'
# b'609,2002,Jimmy Neutron: Attack of the Twonkies\n'
# b'610,1999,Offspring: Americana\n'
# b'611,2004,Spooks & Creeps\n'
# b'612,1946,Cloak and Dagger\n'
# b'613,1965,The Dr. Who Collection\n'
# b'614,1993,Bad Boy Bubby\n'
# b'615,1999,An Ideal Husband\n'
# b'616,1983,SCTV Network 90: Vol. 4\n'
# b'617,2004,UFC: Ultimate Fighting Championship: Ultimate Knockouts 3\n'
# b'618,1994,Totally F***ed Up\n'
# b'619,1980,Doctor Who: The Leisure Hive\n'
# b'620,2003,Hot Wheels: World Race\n'
# b'621,1997,Armageddon\n'
# b"622,1991,Talkin' Dirty After Dark\n"
# b'623,1986,Dario Argento Collection: Vol. 2: Demons 2\n'
# b'624,2004,My Mother Likes Women\n'
# b'625,1999,Underground Comedy Movie\n'
# b'626,1941,They Died with Their Boots On\n'
# b'627,1971,Beware of a Holy Whore\n'
# b'628,2003,Rescue Heroes: The Movie\n'
# b'629,1984,Firestarter\n'
# b'630,1977,Empire of the Ants\n'
# b'631,2005,Unleashed\n'
# b"632,1972,Shaft's Big Score!\n"
# b'633,1993,Baazigar\n'
# b'634,1989,Christmas with The Simpsons\n'
# b'635,1971,The Fassbinder Collection: Pioneer in Ingolstadt\n'
# b'636,1980,Stir Crazy\n'
# b'637,2001,National Geographic: Inside American Power: Air Force One\n'
# b'638,1985,The Last Dragon\n'
# b'639,2002,Jim Brown: All-American\n'
# b'640,1992,To Catch a Killer\n'
# b'641,1968,Charly\n'
# b'642,1990,Mystery Science Theater 3000: The Hellcats\n'
# b'643,2002,Buying the Cow\n'
# b'644,1994,Cheyenne Warrior\n'
# b'645,2004,Dear Frankie\n'
# b'646,1987,Matewan\n'
# b'647,1960,Cinderfella\n'
# b'648,2003,John Mayall & The Bluesbreakers and Friends: 70th Birthday Concert\n'
# b'649,1999,Ricky Martin: The Ricky Martin Video Collection\n'
# b"650,2002,Elvira's Haunted Hills\n"
# b'651,1997,The Rainbow Fish / Dazzle the Dinosaur\n'
# b"652,1996,Marvin's Room\n"
# b'653,2000,American Tragedy\n'
# b'654,1975,Return of the Chinese Boxer\n'
# b'655,1965,Green Acres: Season 1\n'
# b'656,2004,Veronica 2030\n'
# b'657,1996,Highlander: Season 5\n'
# b'658,1991,Robin Hood: Prince of Thieves\n'
# b'659,1972,The Last House on the Left\n'
# b'660,2000,Saving Grace\n'
# b'661,2002,Who is Cletis Tout?\n'
# b'662,1995,Rob Roy\n'
# b'663,1999,La Femme Nikita: Season 3\n'
# b'664,1997,Office Killer\n'
# b'665,1976,Lipstick\n'
# b'666,2000,The Man Who Came to Dinner\n'
# b"667,1965,Gilligan's Island: Season 2\n"
# b'668,2004,Saturday Night Live: The Best of Will Ferrell 2\n'
# b'669,1986,Real Kung Fu of Shaolin\n'
# b'670,2002,He Loves Me, He Loves Me Not\n'
# b'671,1989,The Winter People\n'
# b'672,1991,He Said, She Said\n'
# b'673,1999,Fight Club: Bonus Material\n'
# b'674,1988,Hellbound: Hellraiser II\n'
# b"675,2004,Rugrats All Grown Up: O' Brother!\n"
# b'676,1998,Mafia!\n'
# b'677,2001,In the Mood for Love\n'
# b'678,1965,Loves of a Blonde\n'
# b'679,1990,R.E.M.: Pop Screen\n'
# b'680,2000,Better Than Sex\n'
# b'681,1986,Police Academy 3: Back in Training\n'
# b'682,1998,The Mighty\n'
# b'683,1951,Cavalry Charge\n'
# b'684,1995,Visitors of the Night\n'
# b'685,1999,Running Out of Time\n'
# b'686,2000,Bedazzled\n'
# b'687,2003,Peter Jennings Reports: The Kennedy Assassination: Beyond Conspiracy\n'
# b'688,2003,The History Channel Presents: The Alamo\n'
# b'689,1998,One True Thing\n'
# b'690,2004,Baby Einstein: Baby Da Vinci\n'
# b"691,1999,Angel's Dance\n"
# b'692,1992,The Hand that Rocks the Cradle\n'
# b'693,1996,The Quest\n'
# b'694,2000,When Dinosaurs Roamed America\n'
# b'695,2004,Koma\n'
# b'696,1996,Last Man Standing\n'
# b"697,2000,Caillou: Caillou's Treasure Hunt and Other Adventures\n"
# b'698,1997,Daud\n'
# b'699,2004,Mahoromatic: Automatic Maiden: Summer Special\n'
# b"700,1997,Todd McFarlane's Spawn\n"
# b'701,2002,Nine Lives\n'
# b'702,1996,For the Moment\n'
# b'703,2004,Japan: Memoirs of a Secret Empire\n'
# b'704,1998,A Change of Heart\n'
# b'705,1989,Major League\n'
# b'706,1991,Mobsters\n'
# b'707,2003,The Return\n'
# b'708,2000,The Perfect Storm\n'
# b"709,1998,Africans in America: America's Journey Through Slavery\n"
# b'710,1993,Inspector Morse 9: The Last Enemy\n'
# b'711,1994,Dolores Claiborne\n'
# b'712,1998,Homicide: Life on the Street: Season 7\n'
# b'713,1987,Cause Celebre\n'
# b'714,1988,Whisper Kill\n'
# b'715,1950,Film Noir Collection: D.O.A.\n'
# b'716,1958,The Bravados\n'
# b'717,2004,Testosterone\n'
# b'718,2003,44 Minutes\n'
# b'719,1997,City of Industry\n'
# b'720,1989,Roger & Me\n'
# b'721,1994,Royal Deceit\n'
# b'722,2003,The Wire: Season 1\n'
# b'723,1991,Curly Sue\n'
# b'724,1992,Yu Yu Hakusho\n'
# b'725,2004,Woman Thou Art Loosed\n'
# b'726,1990,The Haunting of Morella\n'
# b'727,1959,Carlton-Browne of the F.O.\n'
# b"728,1977,Abigail's Party\n"
# b'729,2000,Fast Food, Fast Women\n'
# b'730,1988,Bagdad Cafe\n'
# b'731,1997,Mr. Magoo\n'
# b'732,2005,11:14\n'
# b'733,1988,Dead Ringers\n'
# b'734,1992,Indochine\n'
# b'735,2003,Hillary & Tenzing: Climbing to the Roof of World\n'
# b'736,2002,The Last Man\n'
# b'737,2004,Great Pas de Deux\n'
# b'738,1999,A Slipping Down Life\n'
# b'739,2001,Treading Water\n'
# b'740,1988,The House on Carroll Street\n'
# b"741,1988,Ken Burns' America: The Congress\n"
# b'742,2002,Sherlock: Case of Evil\n'
# b"743,1994,Widows' Peak\n"
# b'744,1998,Hot War\n'
# b'745,1979,Fantasy Mission Force\n'
# b'746,2001,Domestic Disturbance\n'
# b'747,1996,Saber Marionette J\n'
# b'748,2002,I Can Do Bad All By Myself\n'
# b'749,1990,Ernest Goes to Jail\n'
# b'750,2004,The Librarian: Quest for the Spear\n'
# b'751,1998,Halloween: H2O\n'
# b'752,1993,Star Trek: The Next Generation: Season 7\n'
# b'753,1964,Mary Poppins: Bonus Material\n'
# b'754,1984,The Lonely Guy\n'
# b'755,1989,Music Box\n'
# b'756,2000,The Best of MusikLaden: Classic Rock\n'
# b'757,1984,Sherlock Hound\n'
# b'758,2004,Mean Girls\n'
# b'759,2001,Fifteen Minutes\n'
# b"760,2005,Pooh's Heffalump Movie\n"
# b'761,2000,O Fantasma\n'
# b'762,2004,End of the Century: The Story of the Ramones\n'
# b'763,1972,The Poseidon Adventure\n'
# b'764,1983,Scarface: 20th Anniversary Edition: Bonus Material\n'
# b'765,1994,Grief\n'
# b'766,1959,A Hole in the Head\n'
# b'767,2001,Edges of the Lord\n'
# b'768,1995,The Star Maker\n'
# b'769,1958,The Crawling Eye\n'
# b'770,1996,A Perfect Candidate\n'
# b'771,1999,Man in the Iron Mask\n'
# b"772,1998,Gloria Estefan: Don't Stop!\n"
# b'773,2001,He Died with a Felafel in His Hand\n'
# b"774,2003,Foyle's War: Set 2\n"
# b'775,1999,Man Ray: Prophet of the Avant Garde\n'
# b"776,1953,Dr. Seuss's The 5,000 Fingers of Dr. T\n"
# b'777,1944,Sherlock Holmes and the Spider Woman\n'
# b'778,2003,A Touch of Frost: Seasons 7 & 8\n'
# b'779,2000,Loving Jezebel\n'
# b'780,2003,Churchill\n'
# b'781,2004,Care Bears: Journey to Joke-a-Lot\n'
# b'782,1998,Soldier of Fortune\n'
# b'783,2001,For Love or Country\n'
# b'784,1995,The Outer Limits: The New Series: Aliens Among Us\n'
# b'785,1981,American Pop\n'
# b'786,1966,Tokyo Drifter\n'
# b'787,1972,La Vallee\n'
# b'788,1994,Clerks\n'
# b'789,1991,Boyz N the Hood\n'
# b'790,2000,A Single Girl\n'
# b'791,2000,Don Henley: Live Inside Job\n'
# b'792,2004,Unsolved History: Salem Witch Trials\n'
# b'793,2004,By Brakhage: An Anthology\n'
# b'794,1992,A Stranger Among Us\n'
# b'795,1997,Landmarks of Early Film\n'
# b'796,1976,Rabid\n'
# b'797,1959,Look Back in Anger\n'
# b'798,1975,Jaws\n'
# b'799,2003,Teen Titans: Season 1\n'
# b'800,1971,Dracula Vs. Frankenstein\n'
# b'801,2001,We Know Where You Live. Live!\n'
# b'802,1928,Spies\n'
# b'803,2001,Soul Assassin\n'
# b'804,1944,Sherlock Holmes: The Scarlet Claw\n'
# b'805,1968,Dark Shadows: Vol. 11\n'
# b'806,1960,Eyes Without a Face\n'
# b'807,1959,The Mouse That Roared\n'
# b'808,1998,Dead Man on Campus\n'
# b'809,2002,Left Behind II: Tribulation Force\n'
# b'810,1958,The Matchmaker\n'
# b'811,1992,The Lawnmower Man\n'
# b'812,2001,The Saddle Club: Horse Crazy\n'
# b'813,2000,On Cukor\n'
# b'814,2000,Ruin Explorers\n'
# b'815,1959,Tiger Bay\n'
# b'816,2001,Marlene Dietrich: Her Own Song\n'
# b'817,1980,My Bodyguard\n'
# b"818,1976,Logan's Run\n"
# b'819,1998,The Faculty\n'
# b'820,2005,Predator Island\n'
# b'821,1972,Slaughter\n'
# b'822,2001,Star Trek: Enterprise: Season 1\n'
# b'823,1988,Sleepaway Camp II: Unhappy Campers\n'
# b'824,1977,A Piece of the Action\n'
# b'825,1983,Bill Cosby: Himself\n'
# b'826,1998,Goosebumps: Cry of the Cat\n'
# b"827,1994,C'est La Vie, Mon Cheri\n"
# b'828,1991,Atlantis\n'
# b'829,1995,Serial Mom\n'
# b'830,1994,Return to a Better Tomorrow\n'
# b'831,1987,Mannequin\n'
# b'832,2003,Tupac: Resurrection\n'
# b'833,1996,White Squall\n'
# b'834,1999,Niagara: Miracles, Myths & Magic: IMAX\n'
# b'835,1994,Cirque du Soleil: A Baroque Odyssey\n'
# b'836,1991,Incident at Oglala: The Leonard Peltier Story\n'
# b'837,1972,All in the Family: Season 3\n'
# b'838,2003,Gang of Roses\n'
# b'839,1945,The Thin Man Goes Home\n'
# b'840,1941,The Lady Eve\n'
# b'841,1994,There Goes My Baby\n'
# b'842,1942,Reap the Wild Wind\n'
# b'843,1999,Mansfield Park\n'
# b'844,2001,La Cienaga\n'
# b'845,2004,If We Had No Moon\n'
# b'846,2004,Enduring Love\n'
# b'847,2001,Shania Twain: The Platinum Collection\n'
# b'848,1994,La Separation\n'
# b'849,1990,Mr. & Mrs. Bridge\n'
# b'850,2002,Stoked: The Rise and Fall of Gator\n'
# b'851,1990,Back to the Future Part III\n'
# b'852,1989,Disorganized Crime\n'
# b'853,1993,Dragonball: The Magic Begins\n'
# b"854,1984,Wes Craven's Invitation to Hell\n"
# b'855,2001,Bruiser\n'
# b'856,2000,Devil in the Flesh 2\n'
# b'857,1963,The Three Stooges Go Around the World in a Daze\n'
# b'858,2002,Sports Illustrated Swimsuit Edition: 2002\n'
# b'859,1982,Creepshow\n'
# b'860,2001,Crime Partners\n'
# b'861,2003,Rush: Rush in Rio\n'
# b'862,2002,Tuck Everlasting\n'
# b'863,1990,King of New York: Special Edition (Full-screen)\n'
# b'864,2001,Laughing Out Loud: Vol. 1\n'
# b'865,2005,Elvis by the Presleys\n'
# b'866,1975,Starsky & Hutch: Season 1\n'
# b'867,2003,My Dream Girl\n'
# b'868,1996,La Promesse\n'
# b'869,1998,Without Limits: NASA Test Projects\n'
# b'870,2005,H.G. Wells and the War of the Worlds: A Documentary\n'
# b'871,1984,The Jewel in the Crown\n'
# b'872,1954,Seven Samurai\n'
# b'873,2003,Boys Life 4: Four Play\n'
# b'874,2004,Elvis Costello & the Imposters: Live in Memphis\n'
# b'875,1998,Zakhm\n'
# b'876,2001,Super Gals\n'
# b'877,1999,A Love Divided\n'
# b'878,2000,Short: International Release #2\n'
# b'879,1976,Mikey and Nicky\n'
# b"880,1994,Sharpe 4: Sharpe's Enemy\n"
# b'881,1999,Mating Habits of the Earthbound Human\n'
# b'882,1996,Gloria Estefan: Evolution Tour: Live in Miami\n'
# b'883,1992,Deep Cover\n'
# b'884,1991,Cup Final\n'
# b'885,2003,The Maldonado Miracle\n'
# b'886,2004,Ray\n'
# b'887,2005,Monster-in-Law: Bonus Material\n'
# b'888,2001,Discovering Australia\n'
# b'889,2004,Reno 911: Season 2\n'
# b'890,1999,Harsh Realm: The Complete Series\n'
# b"891,2003,Zakk Wylde's Black Label Society: Boozed, Broozed & Broken-Boned\n"
# b'892,1965,The Bedford Incident\n'
# b"893,2003,Blue's Clues: Classic Clues\n"
# b'894,1999,The Muse\n'
# b'895,1975,Dersu Uzala\n'
# b'896,1995,Dangerous Minds\n'
# b'897,2004,Bride and Prejudice\n'
# b'898,2000,The Body\n'
# b'899,2003,Out of Ireland: The Hit Songs and Artists of Irish Music\n'
# b'900,1994,Eat Drink Man Woman\n'
# b'901,1950,Diary of a Country Priest\n'
# b'902,2004,Fascination\n'
# b'903,2000,Hamlet\n'
# b'904,2004,Gargoyles\n'
# b'905,2005,Remedy\n'
# b'906,1969,Benny Hill: Complete and Unadulterated: The Naughty Early Years: Set 1\n'
# b'907,1930,Animal Crackers\n'
# b'908,1981,Sense and Sensibility\n'
# b'909,1990,Too Young to Die\n'
# b'910,1940,Santa Fe Trail\n'
# b'911,1939,Buck Rogers\n'
# b'912,2002,Angelina Ballerina: Friends Forever\n'
# b'913,1979,Dead Kennedys: In God We Trust, Inc.\n'
# b'914,1996,R.E.M.: Road Movie\n'
# b'915,2001,Haven\n'
# b'916,1994,Earth 2: The Complete Series\n'
# b'917,2003,String Cheese Incident: Live at the Fillmore\n'
# b"918,1964,A Hard Day's Night: Collector's Series\n"
# b'919,2002,Comedian\n'
# b"920,1968,Satanis: The Devil's Mass / Sinthia: The Devil's Doll: Double Feature\n"
# b"921,1952,Don't Bother to Knock\n"
# b'922,2004,Gojoe: Spirit War Chronicle\n'
# b'923,2004,Giant Robo\n'
# b'924,1981,Taxi Zum Klo\n'
# b'925,1936,Dodsworth\n'
# b'926,2002,Fear Of A Punk Planet\n'
# b"927,1991,Danielle Steel's Changes\n"
# b'928,1997,The Night That Never Happened\n'
# b'929,2002,Journeys with George\n'
# b'930,1987,Back to the Beach\n'
# b'931,1998,Another Day in Paradise\n'
# b'932,1992,Where Are We?\n'
# b"933,2005,Backyardigans: It's Great to Be a Ghost\n"
# b'934,1954,River of No Return\n'
# b'935,2003,Read Or Die\n'
# b'936,1990,A Dangerous Man: Lawrence After Arabia\n'
# b'937,1998,Fallen\n'
# b'938,2002,Scarecrow\n'
# b'939,2003,Midsomer Murders: A Tale of Two Hamlets\n'
# b'940,1997,Hercules\n'
# b'941,1998,Screw Loose\n'
# b'942,1994,The Pagemaster\n'
# b"943,2004,Dave Chappelle: For What It's Worth\n"
# b'944,1975,Brother, Can You Spare a Dime?\n'
# b'945,1952,The Duel at Silver Creek\n'
# b'946,2002,Sex and the Teenage Mind\n'
# b'947,1965,The Cincinnati Kid\n'
# b'948,2002,Aap Mujhe Achche Lagne Lage\n'
# b'949,1997,Henry Fool\n'
# b'950,1998,Explosive Dance\n'
# b'951,2001,Richard Rodgers: The Sweetest Sounds\n'
# b'952,1940,My Favorite Wife\n'
# b'953,1966,Fahrenheit 451\n'
# b'954,2003,I Capture the Castle\n'
# b'955,1997,Rhyme & Reason\n'
# b'956,1994,Blankman\n'
# b'957,1966,Lost in Space: Season 2: Vol. 1\n'
# b'958,2003,World Cup Soccer Highlights: 1966-1974\n'
# b'959,2002,Jay Jay the Jet Plane: Lessons for All Seasons\n'
# b'960,1960,The Unforgiven\n'
# b'961,1957,Love in the Afternoon\n'
# b'962,2002,I Spy\n'
# b'963,1951,A Streetcar Named Desire\n'
# b'964,2001,The Tick: The Entire Series\n'
# b'965,1985,Metropolitan Opera: Puccini: Tosca\n'
# b'966,1996,Young and Dangerous 2\n'
# b'967,2004,Main Hoon Na\n'
# b'968,1993,Dottie Gets Spanked\n'
# b'969,1995,Stripteaser\n'
# b'970,2004,Yesterday Once More\n'
# b'971,2002,Unprecedented: The 2000 Presidential Election\n'
# b'972,2003,Ben Harper: Live at the Hollywood Bowl\n'
# b'973,1994,Dr. Martin Luther King, Jr.: A Historical Perspective\n'
# b'974,1941,The Devil and Daniel Webster\n'
# b'975,1997,Convict 762\n'
# b'976,2003,Tom and Jerry: Paws for a Holiday\n'
# b'977,2000,Our Lady of the Assassins\n'
# b'978,2000,Yi Yi\n'
# b'979,1990,A Moment of Romance\n'
# b'980,1994,The Swan Princess\n'
# b'981,1989,How I Got into College\n'
# b'982,2001,Dil Chahta Hai\n'
# b'983,1997,Wishful Thinking\n'
# b'984,1958,The Young Lions\n'
# b'985,1999,The Mummy\n'
# b'986,2002,The Trip\n'
# b"987,1978,Rescue from Gilligan's Island\n"
# b'988,1951,Operation Pacific\n'
# b'989,2004,The Door in the Floor\n'
# b'990,1941,Meet John Doe\n'
# b'991,1997,Burn Up Excess: Vol. 2: Crimes and Missed Demeanors\n'
# b'992,1972,The Cowboys\n'
# b'993,1994,The Shadow\n'
# b'994,1984,Children of the Corn\n'
# b'995,2004,Dark Town\n'
# b'996,1961,Yojimbo\n'
# b'997,1963,Miracle of the White Stallions\n'
# b'998,2002,Frida: Bonus Material\n'
# b'999,1994,The Favor\n'
# b'1000,2002,Jim Breuer: Hardcore\n'
# b'1001,2001,Blow Dry\n'
# b'1002,2001,The Cazalets\n'
# b'1003,2001,Basic Elements: My Complete Fitness Guide\n'
# b'1004,2003,Bookies\n'
# b'1005,2003,Only the Strong Survive\n'
# b'1006,1996,Inspector Morse 30: The Daughters of Cain\n'
# b"1007,1996,America's Dream\n"
# b"1008,1996,Ken Burns' The West\n"
# b'1009,1997,Judaai\n'
# b'1010,2004,Sesame Street: Sing, Hoot & Howl\n'
# b'1011,1983,All the Right Moves\n'
# b'1012,1960,13 Ghosts\n'
# b'1013,2005,My Scene Goes Hollywood: The Movie\n'
# b'1014,1993,Pretty Boy\n'
# b'1015,1996,Dr. Quinn, Medicine Woman: Season 5\n'
# b'1016,1976,The Killer Inside Me\n'
# b'1017,1955,I Love Lucy: Season 5\n'
# b'1018,1960,Le Petit Soldat\n'
# b'1019,2001,Diamond Hunters\n'
# b'1020,1989,The Simpsons: Season 1\n'
# b'1021,1984,Cloak & Dagger\n'
# b'1022,1993,The Snapper\n'
# b'1023,1997,Sesame Street: Elmo Saves Christmas\n'
# b'1024,1976,The Return of a Man Called Horse\n'
# b'1025,2004,The Eye 2\n'
# b'1026,1985,Silver Bullet\n'
# b'1027,1993,Rising Sun\n'
# b'1028,2003,The Educational Archives: Vol. 1: Sex & Drugs\n'
# b'1029,1995,Tromeo and Juliet\n'
# b'1030,1974,Frank Sinatra: The Main Event\n'
# b'1031,1999,Poirot: The Murder of Roger Ackroyd\n'
# b'1032,1992,Hard Boiled\n'
# b'1033,1999,Spy Games\n'
# b'1034,2000,The New Eve\n'
# b'1035,1994,Disclosure\n'
# b'1036,1999,Coral Sea Dreaming\n'
# b'1037,1978,Attack of the Killer Tomatoes\n'
# b'1038,2000,Boogiepop Phantom\n'
# b'1039,1997,Lawn Dogs\n'
# b"1040,2004,Thomas & Friends: Thomas's Snowy Surprise\n"
# b'1041,2000,Baby Mozart\n'
# b'1042,1996,Forgotten Silver\n'
# b'1043,1987,Outrageous Fortune\n'
# b'1044,1968,The Party\n'
# b'1045,1988,For Keeps\n'
# b'1046,2003,Uptown Girls\n'
# b'1047,2000,Aimee and Jaguar\n'
# b'1048,1997,Year of the Horse: Neil Young & Crazy Horse Live\n'
# b'1049,1991,The Object of Beauty\n'
# b'1050,1982,Annie: Special Anniversary Edition\n'
# b'1051,1994,Blue Chips\n'
# b'1052,1952,The Jack Benny Show: Vol. 1\n'
# b'1053,1997,Mysteries of Magic: Vol. 1\n'
# b'1054,1986,Odin: Photon Space Sailer Starlight\n'
# b'1055,1977,The Duellists\n'
# b'1056,1962,The War Lover\n'
# b'1057,1989,Doctor Who: Ghost Light\n'
# b'1058,1972,Play it Again, Sam\n'
# b'1059,2000,Extreme Bloopers: Sports Gone Wrong\n'
# b"1060,2005,King's Ransom\n"
# b'1061,2004,Spider-Man vs. Doc Ock\n'
# b'1062,1974,California Split\n'
# b'1063,1995,Hemp Revolution\n'
# b'1064,1983,Armored Trooper Votoms Stage 2: Kummen Jungle Wars\n'
# b'1065,2001,Jackpot\n'
# b'1066,1978,Superman: The Movie\n'
# b'1067,1956,Earth vs. The Flying Saucers\n'
# b'1068,1998,Ringu\n'
# b'1069,2003,The Inspector Lynley Mysteries: A Suitable Vengeance\n'
# b'1070,2000,Bangkok Dangerous\n'
# b'1071,1995,The Ice Princess\n'
# b'1072,2000,As Time Goes By: Series 8\n'
# b'1073,2005,Coach Carter\n'
# b'1074,1946,The Postman Always Rings Twice\n'
# b'1075,2001,Tape\n'
# b'1076,2004,American Chopper: Season 2\n'
# b'1077,1945,Leave Her to Heaven\n'
# b'1078,2000,After the Storm\n'
# b'1079,1991,The Gambler Returns: The Luck of the Draw\n'
# b'1080,2002,Hysterical Blindness\n'
# b'1081,2002,Back by Midnight\n'
# b"1082,1997,Flood: A River's Rampage\n"
# b'1083,1962,Tales of Terror\n'
# b'1084,2001,Walking with Prehistoric Beasts\n'
# b'1085,2003,Bright Leaves\n'
# b'1086,1938,Three Stooges: Stooges at Work\n'
# b'1087,1994,Monkey Trouble\n'
# b'1088,1980,Hammer House of Horror\n'
# b'1089,2000,The Land Before Time VII: Stone of Cold Fire\n'
# b'1090,1997,Eel\n'
# b'1091,1980,Dostana\n'
# b'1092,1996,Thin Line Between Love & Hate\n'
# b'1093,1980,The Leg Fighters\n'
# b'1094,2002,Nicholas Nickleby\n'
# b'1095,2004,Vendetta: No Conscience, No Mercy\n'
# b'1096,1989,Harlem Nights\n'
# b"1097,2005,Winning Strategies: Texas Hold 'Em Poker with Mike Caro\n"
# b'1098,1965,The Battle of Algiers\n'
# b'1099,1983,Confidentially Yours\n'
# b'1100,2000,Dr. T & the Women\n'
# b'1101,1976,The Slipper and the Rose\n'
# b'1102,2001,Training Day\n'
# b'1103,1997,Jane Eyre\n'
# b'1104,1983,Krull\n'
# b'1105,1993,RoboCop 3\n'
# b'1106,1998,Virtual Girl\n'
# b'1107,2004,NBA Street Series: Ankle Breakers: Vol. 2\n'
# b'1108,2000,Dr. Andrew Weil: 8 Weeks to Optimum Health & Spontaneous Healing\n'
# b'1109,1964,My Fair Lady: Special Edition: Bonus Material\n'
# b'1110,2003,Secondhand Lions\n'
# b'1111,1972,Cries and Whispers\n'
# b'1112,1957,The Delicate Delinquent\n'
# b'1113,1998,Lost Universe\n'
# b"1114,1929,Hell's Angels\n"
# b'1115,1991,Hammers Over the Anvil\n'
# b'1116,1984,Runaway\n'
# b'1117,1991,Vegas in Space\n'
# b'1118,1980,Moscow Does Not Believe in Tears\n'
# b'1119,2005,Pink Floyd: Inside Pink Floyd: A Critical Review 1975-1996\n'
# b'1120,1982,Quest for Fire\n'
# b'1121,2001,MVP 2:  Most Vertical Primate\n'
# b'1122,1980,The Attic / Crawl Space (Double Feature)\n'
# b'1123,1993,Dragon: The Bruce Lee Story\n'
# b'1124,1932,Rain\n'
# b'1125,2001,Automotive Series: Porsche\n'
# b'1126,2003,Uncovered: The Whole Truth About the Iraq War\n'
# b"1127,1973,Clive Barker's Salome / The Forbidden\n"
# b"1128,1971,Sweet Sweetback's Baadasssss Song\n"
# b'1129,1935,Mutiny on the Bounty\n'
# b'1130,1991,Impromptu\n'
# b'1131,1965,Chained Girls / Daughters of Lesbos: Double Feature\n'
# b'1132,1994,Romeo is Bleeding\n'
# b'1133,2003,Malibu Spring Break\n'
# b'1134,2005,Empire Falls\n'
# b'1135,1996,Paradise Lost: The Child Murders at Robin Hood Hills\n'
# b'1136,1993,Naked\n'
# b"1137,2004,Artie Lange: It's the Whiskey Talkin'\n"
# b'1138,2003,Freddy vs. Jason\n'
# b"1139,2003,Wolf's Rain\n"
# b'1140,1996,To Gillian on her 37th Birthday\n'
# b'1141,2004,Kyun! Ho Gaya Na\n'
# b'1142,1981,Polyester\n'
# b'1143,1943,Phantom of the Opera\n'
# b'1144,1991,Fried Green Tomatoes\n'
# b'1145,2001,The Wedding Planner\n'
# b'1146,1983,Fearless Hyena 1 / Fearless Hyena 2\n'
# b'1147,1983,To the Lighthouse\n'
# b'1148,1981,For Your Eyes Only\n'
# b'1149,2001,Electric Light Orchestra: Zoom Tour Live\n'
# b'1150,2000,Hate.com\n'
# b'1151,2001,Valentine\n'
# b'1152,1999,Charisma\n'
# b'1153,1943,On Approval\n'
# b'1154,1971,Twitch of the Death Nerve\n'
# b'1155,1980,Magnum P.I.: Season 1\n'
# b'1156,2004,Being Ron Jeremy\n'
# b'1157,1997,Chinese Box\n'
# b"1158,2004,I Do (But I Don't)\n"
# b'1159,1961,Rocky & Bullwinkle: The Best of Fractured Fairy Tales: Vol. 1\n'
# b'1160,1999,In Too Deep\n'
# b'1161,2000,Take Me Home: The John Denver Story\n'
# b'1162,2003,Onmyoji 2\n'
# b'1163,1984,2010: The Year We Make Contact\n'
# b'1164,1980,Return of the Secaucus 7\n'
# b'1165,1999,Witness Protection\n'
# b'1166,1950,Great Rupert\n'
# b'1167,1999,La Buche\n'
# b'1168,2004,Rodney Dangerfield: No Respect: The Ultimate Collection\n'
# b'1169,1997,Bjork: Shepherds Bush Empire\n'
# b'1170,1997,Truth or Consequences, N.M.\n'
# b'1171,2001,RoboCop: Crash and Burn\n'
# b"1172,1998,Krippendorf's Tribe\n"
# b'1173,1999,Walking with Dinosaurs\n'
# b'1174,1993,The Sandlot\n'
# b'1175,1984,Repo Man\n'
# b"1176,2001,The Devil's Backbone\n"
# b'1177,2004,Essential Music Videos: Totally 80s\n'
# b'1178,1932,Boudu Saved from Drowning\n'
# b'1179,1997,The Education of Little Tree\n'
# b'1180,2001,A Beautiful Mind\n'
# b'1181,2003,Rolie Polie Olie: Springy-Time Fun\n'
# b'1182,1978,Gray Lady Down\n'
# b'1183,1980,Night of the Hunted\n'
# b'1184,2004,The Wizard of Oz\n'
# b'1185,1998,Mischievous\n'
# b'1186,1939,Jamaica Inn\n'
# b'1187,1971,The Abominable Dr. Phibes\n'
# b'1188,2002,A Little Inside\n'
# b'1189,1986,Aida: Giuseppe Verdi: Teatro Alla Scala\n'
# b'1190,1996,The Late Shift\n'
# b'1191,1997,Most Wanted\n'
# b"1192,2004,Masters of Poker: Phil Hellmuth's Million Dollar Texas Hold'em Tournament Strategies\n"
# b'1193,1998,Beloved\n'
# b'1194,1997,Fall\n'
# b'1195,1988,Madonna: The Girlie Show: Live Down Under\n'
# b'1196,2004,Secrets of Lost Empires 2: Medieval Siege\n'
# b'1197,1999,50 Years: The Best of Hollywood\n'
# b"1198,1971,The Cat O'Nine Tails\n"
# b'1199,1975,Queen of the Stardust Ballroom\n'
# b'1200,1999,Teaching Mrs. Tingle\n'
# b'1201,1991,True Colors\n'
# b"1202,1983,National Lampoon's Vacation\n"
# b"1203,1963,The Andy Griffith Show: Vol 3: Andy Discovers America / Andy's English Valet\n"
# b'1204,1990,Iron & Silk\n'
# b'1205,1994,Dragstrip Girl\n'
# b'1206,2005,Bratz: Rock Angelz\n'
# b'1207,1962,Experiment in Terror\n'
# b'1208,1963,The Twilight Zone: Vol. 15\n'
# b'1209,1976,Swashbuckler\n'
# b'1210,1981,Zorro, The Gay Blade\n'
# b'1211,2004,Modigliani\n'
# b'1212,1988,Red Dwarf: Series 2: Bonus Material\n'
# b'1213,1999,VeggieTales: Madame Blueberry\n'
# b'1214,1972,Bawarchi\n'
# b'1215,1987,Walk Like a Man\n'
# b'1216,1993,Fire in the Sky\n'
# b"1217,2001,Dragon Tales: Let's Share! Let's Play!\n"
# b'1218,1972,Frenzy\n'
# b'1219,2003,Blind Shaft\n'
# b'1220,2004,Man on Fire\n'
# b'1221,1980,Seems Like Old Times\n'
# b'1222,1979,Little House on the Prairie: Season 6\n'
# b'1223,1999,Hard\n'
# b'1224,1947,The Ghost and Mrs. Muir\n'
# b'1225,2000,Jim Breuer: Heavy Metal Comedy\n'
# b"1226,1971,Summer of '42\n"
# b'1227,2005,The Horror Within\n'
# b"1228,2004,The Carol Burnett Show: Let's Bump Up the Lights!\n"
# b'1229,1994,Speechless\n'
# b'1230,2005,Carlos Mencia: Not for the Easily Offended: Live in San Jose\n'
# b'1231,1999,Batman Beyond: Tech Wars / Disappearing Inque\n'
# b'1232,1927,It\n'
# b'1233,2002,Repli-Kate\n'
# b'1234,1994,Crooklyn\n'
# b'1235,1998,The Great Battles of World War II: Battle of Russia\n'
# b'1236,2002,Ali G Indahouse\n'
# b'1237,1999,The Stars of Star Wars\n'
# b'1238,1984,The Pope of Greenwich Village\n'
# b'1239,1973,The Arena\n'
# b'1240,1950,Destination Moon\n'
# b'1241,1945,The Story of G.I. Joe\n'
# b'1242,2005,Billy Blanks: Tae Bo: Fat Blasting Cardio\n'
# b'1243,1998,La Femme Nikita: Season 2\n'
# b'1244,2002,Sex with Strangers\n'
# b'1245,1994,Threesome\n'
# b'1246,1994,Gunmen\n'
# b"1247,2005,Warren Miller's Impact\n"
# b'1248,2002,The Real Eve\n'
# b'1249,1978,Taxi: Season 1\n'
# b'1250,1996,Brassed Off\n'
# b'1251,2002,Frankenthumb\n'
# b'1252,1975,The Story of O\n'
# b'1253,1949,The Barkleys of Broadway\n'
# b'1254,1957,Designing Woman\n'
# b'1255,1985,Better Off Dead\n'
# b'1256,1994,The Best of Friends: Vol. 4\n'
# b'1257,2003,Tupperware!: American Experience\n'
# b'1258,1942,Wake Island\n'
# b'1259,2002,David Gilmour in Concert\n'
# b'1260,1999,Journey to the Center of the Earth\n'
# b'1261,2005,Mojados: Through the Night\n'
# b"1262,1982,Dead Men Don't Wear Plaid\n"
# b'1263,1979,Snake & Crane Arts of Shaolin\n'
# b'1264,2000,The Closet\n'
# b'1265,1971,Women in Cages\n'
# b'1266,2003,Ghosts of the Abyss\n'
# b'1267,2001,Dr. Dolittle 2\n'
# b'1268,2005,Martha Stewart Holidays: Homemade Holidays\n'
# b'1269,1991,29th Street\n'
# b'1270,2000,The Great Gatsby\n'
# b'1271,1939,Drums Along the Mohawk\n'
# b'1272,1953,Island in the Sky\n'
# b'1273,1999,The Thrill Seekers\n'
# b'1274,1984,At Close Range\n'
# b'1275,2004,NBA Street Series: Dunks!: Vol. 2\n'
# b'1276,1978,Challenge of the Superfriends: Attack of the Legion of Doom\n'
# b'1277,1988,Red Dwarf: Series 3\n'
# b'1278,1990,The Field\n'
# b'1279,1969,The Hee Haw Collection\n'
# b'1280,1989,Campion: Look to the Lady\n'
# b'1281,1986,Royal Warriors\n'
# b"1282,2002,Blind Spot: Hitler's Secretary\n"
# b"1283,2001,Inch' Allah Dimanche\n"
# b'1284,2000,Foul King\n'
# b'1285,2001,Phase IV\n'
# b'1286,1997,Welcome Back, Mr. McDonald\n'
# b'1287,1977,Breaker Breaker\n'
# b'1288,2004,10 Minute Solution: Pilates\n'
# b"1289,1990,Look Who's Talking Too\n"
# b"1290,2000,Hitler's Lost Sub: Nova\n"
# b'1291,1960,The Twilight Zone: Vol. 19\n'
# b'1292,2002,Ararat\n'
# b'1293,1996,Children of the Corn 4: The Gathering\n'
# b'1294,2004,The Gunman\n'
# b'1295,1983,Strange Brew\n'
# b'1296,1994,No Ordinary Love\n'
# b'1297,1999,Agnes Browne\n'
# b'1298,2000,Hellraiser V: Inferno\n'
# b'1299,1972,Scooby-Doo Meets Batman\n'
# b'1300,1973,Return of the Dragon\n'
# b'1301,2000,Chasing Sleep\n'
# b'1302,1983,The Indomitable Teddy Roosevelt\n'
# b'1303,2001,Horse Crazy\n'
# b'1304,2003,Moon Child\n'
# b'1305,2003,Thirteen\n'
# b'1306,2005,Baby Einstein: Baby Monet: Discovering the Seasons\n'
# b'1307,2003,S.W.A.T.\n'
# b'1308,1959,No Name on the Bullet\n'
# b"1309,1982,Jammin' with the Blues Greats\n"
# b'1310,2002,Revelation\n'
# ...
# b'17352,1972,Blood Freak\n'
# b'17353,2002,Scratch: Bonus Material\n'
# b'17354,2004,David Copperfield: Illusion\n'
# b'17355,2004,The Terminal\n'
# b'17356,1990,Book of Love\n'
# b'17357,1984,The River\n'
# b'17358,2002,Narc\n'
# b'17359,1984,Falling in Love\n'
# b'17360,2003,The Jamie Kennedy Experiment: Season 3\n'
# b'17361,2004,Johnson Family Vacation\n'
# b'17362,1982,Evilspeak\n'
# b'17363,1985,227: Season 1\n'
# b'17364,2002,Jethro Tull: Living With the Past\n'
# b'17365,1974,Classic Courtroom Movies: Mesmerized / Death Sentence / Dishonored Lady\n'
# b"17366,2002,Bob Mann's Automatic Golf\n"
# b'17367,2002,The Intended\n'
# b'17368,1989,Slipstream\n'
# b'17369,2000,Thug Immortal: The Tupac Shakur Story\n'
# b'17370,1994,The Magic School Bus: Space Adventures\n'
# b'17371,1979,Orchestra Rehearsal\n'
# b'17372,1998,Out of Season\n'
# b'17373,1998,Flowers of Shanghai\n'
# b'17374,2003,American Mystery! Coyote Waits\n'
# b'17375,2001,Ocean Wilds: Realm of the Killer Whales/Sperm Whale Oasis\n'
# b'17376,1997,Amityville Dollhouse\n'
# b'17377,2000,Louis Armstrong: Satchmo\n'
# b"17378,1974,That's Entertainment\n"
# b'17379,1980,The Stunt Man\n'
# b'17380,1993,Inspector Morse 26: Deadly Slumber\n'
# b'17381,2002,Spellbound\n'
# b'17382,1947,Odd Man Out\n'
# b'17383,1952,Carrie\n'
# b'17384,1983,Reilly: Ace of Spies\n'
# b'17385,1995,The Scarlet Letter\n'
# b'17386,1950,Stage Fright\n'
# b'17387,2002,Secretary\n'
# b'17388,1973,The Yakuza Papers\n'
# b'17389,1947,Black Narcissus\n'
# b'17390,1967,A Guide for the Married Man\n'
# b'17391,2003,Wildboyz: Season 1\n'
# b'17392,2001,Dance of a Dream\n'
# b'17393,1993,Body of Evidence\n'
# b'17394,1999,In the Shadows\n'
# b"17395,2004,Breakin' All the Rules\n"
# b'17396,1999,The Taste of Others\n'
# b'17397,1990,In Living Color: Season 1\n'
# b'17398,2004,Cursed\n'
# b"17399,1959,Elvira's Horror Classics\n"
# b'17400,1967,The Rape of the Vampire\n'
# b'17401,1979,The Champ\n'
# b'17402,1990,Europa Europa\n'
# b'17403,2004,Scooby-Doo and the Loch Ness Monster\n'
# b'17404,2003,Watching You\n'
# b'17405,2005,Sahara\n'
# b'17406,1998,Apocalypse\n'
# b'17407,1954,Suddenly\n'
# b'17408,1956,X the Unknown\n'
# b'17409,2005,Blast!\n'
# b"17410,2002,The True Meaning of Pictures: Shelby Lee Adams' Appalachia\n"
# b'17411,1953,How to Marry a Millionaire\n'
# b'17412,1948,The Treasure of the Sierra Madre\n'
# b'17413,2004,Resident Evil: Apocalypse: Bonus Material\n'
# b'17414,1963,Black Sabbath\n'
# b'17415,1987,Steel Dawn\n'
# b'17416,1997,Aur Pyar Ho Gaya\n'
# b'17417,1999,Breakfast of Champions\n'
# b'17418,1979,The Tin Drum\n'
# b"17419,1974,It's the Easter Beagle, Charlie Brown\n"
# b"17420,1984,The Razor's Edge\n"
# b'17421,1986,Brotherhood of Justice\n'
# b'17422,1971,How to Frame a Figg\n'
# b'17423,2004,The Five People You Meet in Heaven\n'
# b'17424,1976,The Outlaw Josey Wales\n'
# b'17425,2000,Best of Boys in Love\n'
# b'17426,1953,Peter Pan\n'
# b'17427,2005,WWE: No Way Out\n'
# b'17428,2002,Eye See You\n'
# b'17429,2005,Vampire Assassins\n'
# b'17430,2000,Combat Vietnam: To Hell and Beyond\n'
# b'17431,1998,Run Lola Run\n'
# b'17432,1998,Orphen\n'
# b'17433,1936,Follow the Fleet\n'
# b'17434,1959,The Hound of the Baskervilles\n'
# b'17435,1987,Hope and Glory\n'
# b'17436,2004,Laguna Beach: Season 1\n'
# b'17437,2004,Appleseed\n'
# b'17438,1986,True Stories: Talking Heads\n'
# b'17439,1994,I Spy Returns\n'
# b'17440,1945,Captain Kidd\n'
# b'17441,1982,Tootsie\n'
# b'17442,2002,Written in Blood\n'
# b"17443,2003,Blue's Clues: Shapes and Colors\n"
# b'17444,1992,RG Veda\n'
# b'17445,1969,Rascal\n'
# b'17446,1954,Three Coins in the Fountain\n'
# b'17447,1959,The Angry Red Planet\n'
# b'17448,1999,Thumb Wars: The Phantom Cuticle\n'
# b'17449,2004,Born Into Brothels\n'
# b'17450,2001,Fosse\n'
# b'17451,2000,Along for the Ride\n'
# b'17452,2003,Spy Kids 3-D: Game Over (2-D version)\n'
# b'17453,2003,Marci X\n'
# b'17454,2002,Patlabor WXIII: The Movie\n'
# b'17455,1998,Jeremiah: The Bible\n'
# b'17456,1999,Lansky\n'
# b'17457,2000,Sound and Fury\n'
# b'17458,1991,Black Robe\n'
# b'17459,1972,Buck and the Preacher\n'
# b'17460,1952,Wages of Fear\n'
# b'17461,1984,Making the Grade\n'
# b'17462,2001,Doomsdayer\n'
# b'17463,2001,Diary of a Sex Addict\n'
# b'17464,1973,The Legend of Hell House\n'
# b'17465,1973,Dillinger\n'
# b'17466,2000,Sex: The Annabel Chong Story\n'
# b'17467,1977,Slap Shot: 25th Anniversary Edition\n'
# b'17468,1945,Anchors Aweigh\n'
# b'17469,1961,The Misfits\n'
# b'17470,2004,ABC News Presents: NYPD 24/7\n'
# b'17471,1987,Eastern Condors\n'
# b'17472,1973,Magnum Force\n'
# b'17473,2002,Leela\n'
# b'17474,1964,My Fair Lady: Special Edition\n'
# b'17475,1951,It Came From Outer Space\n'
# b'17476,1972,The Waltons: Season 1\n'
# b'17477,1991,Giuseppe Verdi: Attila: Teatro Alla Scala\n'
# b'17478,1994,Men of War\n'
# b'17479,2002,The Ring\n'
# b'17480,2003,The Shield: Season 2\n'
# b'17481,1989,The NeverEnding Story 2: The Next Chapter\n'
# b'17482,1995,Clueless\n'
# b'17483,2003,Crocodile Hunter: Wildest Home Videos / Big Croc Diaries\n'
# b'17484,2001,F. Scott Fitzgerald: Winter Dreams\n'
# b'17485,2004,Prom Queen\n'
# b'17486,2002,Dahmer\n'
# b'17487,1991,Career Opportunities\n'
# b'17488,1981,Genocide\n'
# b'17489,2000,B.B. King: The Jazz Channel Presents: BET on Jazz\n'
# b'17490,1997,Fairy Tale: A True Story\n'
# b'17491,2002,Like Mike\n'
# b'17492,2004,Going Upriver: The Long War of John Kerry\n'
# b'17493,2004,Steve-O: The Early Years\n'
# b'17494,1986,F/X\n'
# b'17495,2002,Pinero\n'
# b'17496,2002,The Nightmare Room: Camp Nowhere\n'
# b'17497,2002,Kurosawa: A Documentary on the Acclaimed Director\n'
# b'17498,1999,The Minus Man\n'
# b'17499,1998,Mulan: Special Edition\n'
# b'17500,2001,Exodus Revealed\n'
# b'17501,1955,Dr. Jekyll and Mr. Hyde\n'
# b'17502,1992,Moon Warriors\n'
# b'17503,1994,Fando & Lis / Constellation Jodorowsky\n'
# b'17504,1994,Without Warning\n'
# b'17505,1999,Dil To Pagal Hai\n'
# b'17506,2004,Little Black Book\n'
# b'17507,1994,Mommy\n'
# b'17508,2000,Requiem for a Dream\n'
# b"17509,1984,Breakin'\n"
# b'17510,2004,Stella Street\n'
# b'17511,1999,Cher: Live in Concert\n'
# b'17512,2002,Amen.\n'
# b'17513,1999,Varsity Blues\n'
# b'17514,2000,The Lifestyle: Swinging in America\n'
# b'17515,2003,LeapFrog: Letter Factory\n'
# b'17516,1962,The Three Stooges Meet Hercules\n'
# b'17517,2004,Strange Bedfellows\n'
# b'17518,1999,Fallen Angel\n'
# b'17519,2001,Bellydance Fitness for Beginners: Slim Down\n'
# b'17520,1974,Bruce Lee: A Dragon Story\n'
# b'17521,2000,Neale Donald Walsch: On Abundance and Holistic Living\n'
# b'17522,1983,Cross Creek\n'
# b'17523,1990,Campion: Sweet Danger\n'
# b'17524,1950,Cyrano de Bergerac\n'
# b'17525,1957,The Enemy Below\n'
# b'17526,1959,Some Like It Hot\n'
# b'17527,2000,Essex Boys\n'
# b'17528,2001,Megiddo: The Omega Code 2\n'
# b'17529,2004,Bright Young Things\n'
# b'17530,1979,Macbeth\n'
# b'17531,1990,A Shock to the System\n'
# b'17532,2001,Bear in the Big Blue House: Potty Time with Bear\n'
# b"17533,1966,Who's Afraid of Virginia Woolf?\n"
# b'17534,1996,The Newsroom: The Complete Series\n'
# b'17535,1947,The Bachelor and the Bobby-Soxer\n'
# b'17536,1991,Northern Exposure: Season 2\n'
# b'17537,1984,Bachelor Party\n'
# b'17538,2001,Poirot: Murder in Mesopotamia\n'
# b'17539,1990,Mr. Destiny\n'
# b'17540,2001,Son of the Bride\n'
# b'17541,2004,First Daughter\n'
# b'17542,1999,The True Story of Private Ryan\n'
# b'17543,1995,Hercules: Warrior Princess / Gauntlet / Unchained Heart\n'
# b'17544,1986,Degrassi Junior High: Season 1\n'
# b'17545,2003,Heart\n'
# b'17546,2000,Survivor: Season 1: Borneo\n'
# b'17547,1975,Space: 1999\n'
# b'17548,1979,Don Giovanni\n'
# b'17549,2002,Bloody Sunday\n'
# b'17550,2003,The Gates of Jerusalem\n'
# b'17551,2001,G-Men From Hell\n'
# b'17552,2000,Michael Jordan to the Max: IMAX\n'
# b'17553,1998,Swing Craze\n'
# b'17554,1998,Wide Awake\n'
# b'17555,2002,The Kid Stays in the Picture\n'
# b'17556,1984,November Moon\n'
# b'17557,2002,In Memoriam: New York City 9/11/01\n'
# b'17558,2001,Kiss of the Dragon\n'
# b'17559,2001,The Deep End\n'
# b'17560,1984,Ghostbusters\n'
# b"17561,2002,I'm With Lucy\n"
# b'17562,2004,The Yes Men\n'
# b'17563,1962,Lolita\n'
# b'17564,1999,Battle Athletes Victory: Vol. 2: Doubt and Conflict\n'
# b'17565,1993,Coneheads\n'
# b'17566,2003,Pretenders: Loose in L.A.\n'
# b'17567,1959,Missile to the Moon\n'
# b'17568,2001,The North Face Expeditions: Shishpangma and Himalaya\n'
# b"17569,1960,Davey and Goliath: Vol. 1: Collector's Edition\n"
# b'17570,2000,Strangers with Candy: Season 2\n'
# b'17571,2001,In the Mood for Love: Bonus Material\n'
# b'17572,2000,Bread and Roses\n'
# b'17573,1981,Fort Apache, the Bronx\n'
# b'17574,1996,Eye for an Eye\n'
# b"17575,2001,Don't Tempt Me\n"
# b'17576,2002,Friday Night\n'
# b'17577,2003,Absolution\n'
# b'17578,1990,Reversal of Fortune\n'
# b'17579,2001,Discovering Alaska\n'
# b'17580,2004,The Whole Ten Yards\n'
# b'17581,2001,Me and Mrs. Jones\n'
# b'17582,2003,Line of Control\n'
# b'17583,2004,Cops: Shots Fired\n'
# b'17584,2004,Cat Stevens: Majikat\n'
# b"17585,2000,Bill Engvall's New All-Stars of Country Comedy: Vol. 1\n"
# b'17586,1992,Cool World\n'
# b'17587,1989,Renegades\n'
# b'17588,1993,Full Eclipse\n'
# b'17589,2000,The Cell\n'
# b'17590,1990,Phil Collins: Serious Hits Live\n'
# b"17591,1966,Dr. Seuss' How the Grinch Stole Christmas\n"
# b'17592,2004,Frankenfish\n'
# b'17593,2001,The Man Show: Season 3\n'
# b'17594,2001,The King of Queens: Season 4\n'
# b'17595,2005,Winter Solstice\n'
# b'17596,1973,Shaft in Africa\n'
# b"17597,1969,They Shoot Horses, Don't They?\n"
# b'17598,1962,The Andy Griffith Show: Season 3\n'
# b'17599,2004,Art: 21: Art in the 21st Century: Seasons 1 and 2\n'
# b"17600,2004,James' Journey to Jerusalem\n"
# b'17601,1989,Wiseguy: Between the Mob and a Hard Place\n'
# b'17602,1992,Tokyo Babylon: Vols. 1 & 2\n'
# b'17603,1988,Halloween 4: The Return of Michael Myers\n'
# b'17604,1960,The Entertainer\n'
# b'17605,1964,Roustabout\n'
# b'17606,1971,Cry Uncle\n'
# b'17607,1942,Jungle Book\n'
# b'17608,2004,Serial Slayer\n'
# b'17609,2002,Antibody\n'
# b'17610,1998,Soldier Child\n'
# b'17611,2002,The Legend of Bhagat Singh\n'
# b'17612,1995,The Beatles Anthology\n'
# b'17613,1994,Into the Deep: IMAX\n'
# b'17614,1995,Dead Presidents\n'
# b'17615,2004,Scarecrow Gone Wild\n'
# b'17616,1940,The Westerner\n'
# b'17617,1971,Ginger\n'
# b'17618,1999,The Will Smith Music Video Collection\n'
# b'17619,1947,Out of the Past\n'
# b'17620,1919,Spiders\n'
# b'17621,1997,Tomorrow Never Dies\n'
# b'17622,2001,Vanilla Sky\n'
# b'17623,1947,Crossfire\n'
# b'17624,1995,Free Willy 2: The Adventure Home\n'
# b'17625,1996,Multiplicity\n'
# b'17626,2001,Henry Rollins: Up for It\n'
# b"17627,2001,Harry Potter and the Sorcerer's Stone\n"
# b'17628,1985,Vampire Hunter D\n'
# b'17629,2004,Tales of Seduction by U-Jin\n'
# b'17630,1987,Hangmen\n'
# b'17631,1964,Zulu\n'
# b'17632,1962,Days of Wine and Roses\n'
# b'17633,1998,Joseph and the Amazing Technicolor Dreamcoat\n'
# b"17634,2002,The Best of Too Hot for Troma's Edge TV: Vol. 1\n"
# b'17635,2003,Good Fences\n'
# b'17636,1998,Homo Heights\n'
# b'17637,1957,The Smallest Show on Earth\n'
# b'17638,1997,The Wings of the Dove\n'
# b'17639,1971,Screaming Skull/The Werewolf vs. Vampire Woman\n'
# b'17640,1987,Unsolved Mysteries: Bizarre Murders\n'
# b'17641,1994,Homicide: Life on the Street: Season 4\n'
# b'17642,2000,X-Men: Evolution: Season 1\n'
# b'17643,1984,Supergirl\n'
# b'17644,2002,The Anarchist Cookbook\n'
# b'17645,1999,Classic Albums: U2: The Joshua Tree\n'
# b'17646,2002,BaadAssss Cinema\n'
# b"17647,2003,Carmen Electra's Hip Hop\n"
# b'17648,2003,Beyond Re-Animator\n'
# b'17649,1997,That Old Feeling\n'
# b'17650,1995,Unstrung Heroes\n'
# b'17651,2001,Tum Bin\n'
# b"17652,1958,Teacher's Pet\n"
# b'17653,2002,The Accidental Spy\n'
# b'17654,1999,K-911\n'
# b'17655,2001,10 Attitudes\n'
# b'17656,1980,To Serve Them All My Days\n'
# b'17657,1997,Portishead: Roseland New York Live\n'
# b'17658,1994,The Chase\n'
# b'17659,1994,Hello Brother\n'
# b'17660,2004,Round Trip\n'
# b'17661,1984,The Times of Harvey Milk\n'
# b'17662,2003,The Guru\n'
# b'17663,2002,3-2-1 Penguins: Trouble on Planet Wait-Your-Turn\n'
# b'17664,2002,Pauline and Paulette\n'
# b'17665,1998,Shark Skin Man and Peach Hip Girl\n'
# b'17666,2000,Fleeing by Night\n'
# b'17667,NULL,Eros Dance Dhamaka\n'
# b'17668,1998,Secret Defense\n'
# b'17669,1986,Desert Bloom\n'
# b'17670,1957,Dr. Seuss: The Grinch Grinches The Cat in the Hat\n'
# b'17671,1990,La Femme Nikita\n'
# b'17672,2000,My Dog Skip\n'
# b'17673,1986,Trick or Treat\n'
# b'17674,1997,Cure\n'
# b'17675,1999,The Man Show: Season 1: Vol. 2\n'
# b'17676,2001,Curse of the Erotic Tiki\n'
# b'17677,2000,Saiyuki\n'
# b'17678,2000,Deepak Chopra: Seven Spiritual Laws & The Crystal Cave\n'
# b'17679,1999,Into the Thin Air of Everest: Mountain of Dreams, Mountain of Doom\n'
# b'17680,1995,Poirot: Hickory Dickory Dock\n'
# b'17681,2000,Bread and Tulips\n'
# b'17682,1998,Buffy the Vampire Slayer: Season 3\n'
# b'17683,2002,Die Another Day: Bonus Material\n'
# b'17684,1992,Sherlock Holmes: The Master Blackmailer\n'
# b'17685,1988,Alice\n'
# b'17686,1989,Common Threads: Stories from the Quilt\n'
# b'17687,1997,Oz: Season 3\n'
# b'17688,1996,Hetty Wainthropp Investigates: Series 2\n'
# b'17689,2000,Kiss: Unauthorized Kiss\n'
# b'17690,2003,Nemesis Game\n'
# b'17691,1988,Red Dwarf: Series 3: Bonus Material\n'
# b'17692,2002,Scooby-Doo\n'
# b'17693,1995,Operation Dumbo Drop\n'
# b'17694,1992,Leolo\n'
# b'17695,1979,Going in Style\n'
# b'17696,1985,Ghoulies / Ghoulies II: Double Feature\n'
# b'17697,2004,New York Minute\n'
# b"17698,2004,Popeye's Voyage: Quest for Pappy\n"
# b'17699,1996,3rd Rock from the Sun: Season 1\n'
# b'17700,1986,Mysteries of the Deep: Legendary Shipwrecks: Secrets of the Titanic\n'
# b'17701,1969,Fellini Satyricon\n'
# b'17702,2004,Comic Book: The Movie\n'
# b'17703,2003,Hulk\n'
# b'17704,1999,Taboo\n'
# b'17705,2002,Evil Alien Conquerors\n'
# b'17706,2001,Najica Blitz Tactics\n'
# b'17707,2004,Latter Days\n'
# b'17708,2001,Trembling Before G-d\n'
# b'17709,1992,A River Runs Through It\n'
# b'17710,2003,Going Down\n'
# b'17711,2003,The Diary of Ellen Rimbauer\n'
# b'17712,2004,The Doobie Brothers: Live at Wolf Trap\n'
# b'17713,2004,WWE: Summerslam 2004\n'
# b'17714,1989,The Little Mermaid\n'
# b'17715,1947,The Adventures of Ma and Pa Kettle: Vol. 1\n'
# b'17716,1993,Some Folks Call it a Sling Blade\n'
# b'17717,1991,Sol Bianca: The Legacy: Vol. 3: Going Home\n'
# b'17718,1996,The Delta\n'
# b'17719,1979,The Europeans\n'
# b'17720,1999,Pirates of the Plain\n'
# b'17721,1998,The Love Letter\n'
# b'17722,1984,Faerie Tale Theatre: The Little Mermaid\n'
# b'17723,2004,Redemption\n'
# b'17724,1993,Gettysburg\n'
# b"17725,1999,Jerry Seinfeld: I'm Telling You for the Last Time\n"
# b'17726,1998,Cats\n'
# b"17727,1954,Elizabeth Taylor: The Last Time I Saw Paris/Father's Little Dividend\n"
# b'17728,2000,Me & Isaac Newton\n'
# b'17729,1999,Icebreaker\n'
# b'17730,1958,The Blob\n'
# b'17731,1998,Death Mask\n'
# b'17732,1945,Open City\n'
# b'17733,2002,13th Child: Legend of the Jersey Devil\n'
# b'17734,2002,Shanghai Ghetto\n'
# b'17735,1998,Type O Negative: After Dark\n'
# b'17736,1999,Reptilian\n'
# b'17737,1985,Frank Zappa: Does Humor Belong in Music?\n'
# b'17738,2004,Henry Rollins: Live at Luna Park\n'
# b'17739,1968,Dracula / The Strange Case of Dr. Jekyll and Mr. Hyde\n'
# b'17740,1960,Shoot the Piano Player\n'
# b'17741,2004,Ginger Snaps 2: Unleashed\n'
# b'17742,1995,Catherine the Great\n'
# b'17743,2003,Better Luck Tomorrow\n'
# b'17744,2004,NASCAR: Tony Stewart Smoke\n'
# b'17745,2002,Russell Simmons Presents Def Poetry: Season 1\n'
# b'17746,1991,Godzilla & Mothra: Battle for Earth / Vs. King Ghidora\n'
# b'17747,1991,Eric Clapton: 24 Nights\n'
# b'17748,2005,Dog the Bounty Hunter: The Best of Season 1\n'
# b'17749,1985,No End\n'
# b'17750,2005,The Hee Haw Collection: Vol. 4\n'
# b'17751,1993,Highlander: Season 2\n'
# b'17752,2003,Out of Order\n'
# b'17753,1997,Maslin Beach\n'
# b'17754,1999,On the Ropes\n'
# b'17755,2003,L/R: Licensed by Royalty\n'
# b'17756,1935,The 39 Steps\n'
# b'17757,2002,Ulysses S. Grant: Warrior / President: American Experience\n'
# b'17758,1979,Prophecy\n'
# b'17759,1972,The Big Bird Cage\n'
# b'17760,2004,Lightning Bug\n'
# b'17761,2003,Levity\n'
# b'17762,1997,Gattaca\n'
# b'17763,1978,Interiors\n'
# b'17764,1998,Shakespeare in Love\n'
# b"17765,1969,Godzilla's Revenge\n"
# b'17766,2002,Where the Wild Things Are and Other Maurice Sendak Stories\n'
# b'17767,2004,Fidel Castro: American Experience\n'
# b'17768,2000,Epoch\n'
# b'17769,2003,The Company\n'
# b'17770,2003,Alien Hunter\n'

# %%
#trying a different approach to load files - but not working
movie_titles = pd.read_csv('./data/movie_titles.csv.zip',
                           encoding = 'ISO-8859-1', 
                           header = None, 
                           names = ['Id', 'Year', 'Name']).set_index('Id')

print('Shape Movie-Titles:\t{}'.format(movie_titles.shape))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 #trying a different approach
# ----> 2 movie_titles = pd.read_csv('./data/movie_titles.csv.zip',
#       3                            encoding = 'ISO-8859-1',
#       4                            header = None,
#       5                            names = ['Id', 'Year', 'Name']).set_index('Id')
#       7 print('Shape Movie-Titles:\t{}'.format(movie_titles.shape))
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 72, saw 4

# %%
# Solving error on live 72 of csv

# load all likes as 1 
df = pd.read_csv('./data/movie_titles.csv.zip', 
                 encoding='ISO-8859-1', 
                 header=None, 
                 names=['RawData'], 
                 delimiter='\t'  # Use a non-existing delimiter
                )

# Inspect problematic 
print(df[df['RawData'].str.count(',') > 2])

problem_rows = df[df['RawData'].str.count(',') > 2]

problem_rows.head(10)
# Out:
#                                                  RawData
# 71     72,1974,At Home Among Strangers, A Stranger Am...
# 263    264,2002,Angelina Ballerina: Lights, Camera, A...
# 349         350,1993,Dr. Quinn, Medicine Woman: Season 3
# 365    366,2004,Still, We Believe: The Boston Red Sox...
# 393                394,1916,20,000 Leagues Under the Sea
# ...                                                  ...
# 17346              17347,2002,Read-Along: Monsters, Inc.
# 17418   17419,1974,It's the Easter Beagle, Charlie Brown
# 17572                  17573,1981,Fort Apache, the Bronx
# 17596          17597,1969,They Shoot Horses, Don't They?
# 17678  17679,1999,Into the Thin Air of Everest: Mount...
#
# [336 rows x 1 columns]
#                                                RawData
# 71   72,1974,At Home Among Strangers, A Stranger Am...
# 263  264,2002,Angelina Ballerina: Lights, Camera, A...
# 349       350,1993,Dr. Quinn, Medicine Woman: Season 3
# 365  366,2004,Still, We Believe: The Boston Red Sox...
# 393              394,1916,20,000 Leagues Under the Sea
# 465             466,1990,Doogie Howser, M.D.: Season 2
# 581        582,1986,Jo Jo Dancer, Your Life is Calling
# 599                    600,1966,What's Up, Tiger Lily?
# 669              670,2002,He Loves Me, He Loves Me Not
# 671                         672,1991,He Said, She Said

# %%
# Wrangle data

df = pd.read_csv('./data/movie_titles.csv.zip', 
                 encoding='ISO-8859-1', 
                 header=None, 
                 names=['RawData'], 
                 error_bad_lines=False)

# Split the 'RawData' column into three columns
df[['Id', 'Year', 'Name']] = df['RawData'].str.split(',', 2, expand=True)

# Drop the original 'RawData' column
df = df.drop(columns=['RawData'])

# Replace "NULL" with np.nan
df['Year'] = df['Year'].replace('NULL', np.nan)

# Convert 'Id' and 'Year' to their appropriate data types
df['Id'] = pd.to_numeric(df['Id'])
df['Year'] = pd.to_numeric(df['Year'])

# Set 'Id' as the index
df = df.set_index('Id')

print(df.head())
# Out:
# b'Skipping line 72: expected 3 fields, saw 4\nSkipping line 264: expected 3 fields, saw 5\nSkipping line 350: expected 3 fields, saw 4\nSkipping line 366: expected 3 fields, saw 4\nSkipping line 394: expected 3 fields, saw 4\nSkipping line 466: expected 3 fields, saw 4\nSkipping line 582: expected 3 fields, saw 4\nSkipping line 600: expected 3 fields, saw 4\nSkipping line 670: expected 3 fields, saw 4\nSkipping line 672: expected 3 fields, saw 4\nSkipping line 729: expected 3 fields, saw 4\nSkipping line 776: expected 3 fields, saw 4\nSkipping line 827: expected 3 fields, saw 4\nSkipping line 834: expected 3 fields, saw 4\nSkipping line 891: expected 3 fields, saw 4\nSkipping line 913: expected 3 fields, saw 4\nSkipping line 944: expected 3 fields, saw 4\nSkipping line 973: expected 3 fields, saw 4\nSkipping line 1010: expected 3 fields, saw 4\nSkipping line 1015: expected 3 fields, saw 4\nSkipping line 1058: expected 3 fields, saw 4\nSkipping line 1095: expected 3 fields, saw 4\nSkipping line 1170: expected 3 fields, saw 4\nSkipping line 1210: expected 3 fields, saw 4\nSkipping line 1286: expected 3 fields, saw 4\nSkipping line 1520: expected 3 fields, saw 4\nSkipping line 1559: expected 3 fields, saw 4\nSkipping line 1629: expected 3 fields, saw 4\nSkipping line 1647: expected 3 fields, saw 4\nSkipping line 1654: expected 3 fields, saw 4\nSkipping line 1658: expected 3 fields, saw 4\nSkipping line 1674: expected 3 fields, saw 4\nSkipping line 1745: expected 3 fields, saw 4\nSkipping line 1752: expected 3 fields, saw 4\nSkipping line 2107: expected 3 fields, saw 4\nSkipping line 2176: expected 3 fields, saw 4\nSkipping line 2178: expected 3 fields, saw 4\nSkipping line 2361: expected 3 fields, saw 5\nSkipping line 2410: expected 3 fields, saw 4\nSkipping line 2428: expected 3 fields, saw 4\nSkipping line 2433: expected 3 fields, saw 4\nSkipping line 2462: expected 3 fields, saw 4\nSkipping line 2598: expected 3 fields, saw 4\nSkipping line 2625: expected 3 fields, saw 4\nSkipping line 2628: expected 3 fields, saw 4\nSkipping line 2691: expected 3 fields, saw 4\nSkipping line 2722: expected 3 fields, saw 4\nSkipping line 2772: expected 3 fields, saw 4\nSkipping line 2796: expected 3 fields, saw 4\nSkipping line 2830: expected 3 fields, saw 4\nSkipping line 2854: expected 3 fields, saw 4\nSkipping line 2878: expected 3 fields, saw 4\nSkipping line 2889: expected 3 fields, saw 4\nSkipping line 2947: expected 3 fields, saw 4\nSkipping line 3023: expected 3 fields, saw 4\nSkipping line 3083: expected 3 fields, saw 4\nSkipping line 3140: expected 3 fields, saw 4\nSkipping line 3163: expected 3 fields, saw 4\nSkipping line 3227: expected 3 fields, saw 4\nSkipping line 3238: expected 3 fields, saw 4\nSkipping line 3290: expected 3 fields, saw 4\nSkipping line 3428: expected 3 fields, saw 4\nSkipping line 3429: expected 3 fields, saw 4\nSkipping line 3440: expected 3 fields, saw 4\nSkipping line 3509: expected 3 fields, saw 4\nSkipping line 3561: expected 3 fields, saw 4\nSkipping line 3569: expected 3 fields, saw 4\nSkipping line 3591: expected 3 fields, saw 4\nSkipping line 3595: expected 3 fields, saw 4\nSkipping line 3634: expected 3 fields, saw 4\nSkipping line 3880: expected 3 fields, saw 4\nSkipping line 3933: expected 3 fields, saw 5\nSkipping line 4005: expected 3 fields, saw 4\nSkipping line 4029: expected 3 fields, saw 4\nSkipping line 4059: expected 3 fields, saw 4\nSkipping line 4105: expected 3 fields, saw 4\nSkipping line 4125: expected 3 fields, saw 4\nSkipping line 4153: expected 3 fields, saw 4\nSkipping line 4168: expected 3 fields, saw 4\nSkipping line 4268: expected 3 fields, saw 5\nSkipping line 4325: expected 3 fields, saw 4\nSkipping line 4335: expected 3 fields, saw 4\nSkipping line 4433: expected 3 fields, saw 4\nSkipping line 4436: expected 3 fields, saw 4\nSkipping line 4444: expected 3 fields, saw 5\nSkipping line 4518: expected 3 fields, saw 4\nSkipping line 4550: expected 3 fields, saw 4\nSkipping line 4 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 10
#       3 df = pd.read_csv('./data/movie_titles.csv.zip',
#       4                  encoding='ISO-8859-1',
#       5                  header=None,
#       6                  names=['RawData'],
#       7                  error_bad_lines=False)
#       9 # Split the 'RawData' column into three columns
# ---> 10 df[['Id', 'Year', 'Name']] = df['RawData'].str.split(',', 2, expand=True)
#      12 # Drop the original 'RawData' column
#      13 df = df.drop(columns=['RawData'])
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\core\frame.py:3643, in DataFrame.__setitem__(self, key, value)
#    3641     self._setitem_frame(key, value)
#    3642 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
#    3645     self._set_item_frame_value(key, value)
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\core\frame.py:3685, in DataFrame._setitem_array(self, key, value)
#    3680 else:
#    3681     # Note: unlike self.iloc[:, indexer] = value, this will
#    3682     #  never try to overwrite values inplace
#    3684     if isinstance(value, DataFrame):
# -> 3685         check_key_length(self.columns, key, value)
#    3686         for k1, k2 in zip(key, value.columns):
#    3687             self[k1] = value[k2]
#
# File c:\Users\jk\anaconda3\lib\site-packages\pandas\core\indexers\utils.py:428, in check_key_length(columns, key, value)
#     426 if columns.is_unique:
#     427     if len(value.columns) != len(key):
# --> 428         raise ValueError("Columns must be same length as key")
#     429 else:
#     430     # Missing keys in columns are represented as -1
#     431     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
# Load data for all movies
movie_titles = pd.read_csv('./data/movie_titles.csv.zip', 
                           encoding = 'ISO-8859-1', 
                           header = None, 
                           usecols = range(3),
                           names = ['Id', 'Year', 'Name']).set_index('Id')

movie_titles = movie_titles.fillna("Unknown")

print('Shape Movie-Titles:\t{}'.format(movie_titles.shape))
# movie_titles.sample(80)
movie_titles.head(75)
# Out:
# Shape Movie-Titles:	(17770, 2)
#       Year                                            Name
# Id
# 1   2003.0                                 Dinosaur Planet
# 2   2004.0                      Isle of Man TT 2004 Review
# 3   1997.0                                       Character
# 4   1994.0                    Paula Abdul's Get Up & Dance
# 5   2004.0                        The Rise and Fall of ECW
# ..     ...                                             ...
# 71  1995.0                 Maya Lin: A Strong Clear Vision
# 72  1974.0                         At Home Among Strangers
# 73  1954.0  Davy Crockett: 50th Anniversary Double Feature
# 74  1999.0                                       6ixtynin9
# 75  1997.0                                           Grind
#
# [75 rows x 2 columns]

# %% [markdown]
# There are approximately 18000 movies in the ratings dataset and the metadata information includes the year of release and movie title

# %% [markdown]
# Next, we will load the movie_metadata.csv from The movies dataset source. This is to get the metadata information like description etc. related to each movie.

# %%
# Load a movie metadata dataset
movie_metadata = (pd.read_csv('./data/movies_metadata.csv.zip', 
                              low_memory=False)[['original_title', 'overview', 'vote_count']]
                    .set_index('original_title')
                    .dropna())

# Remove the long tail of rarly rated moves
movie_metadata = movie_metadata[movie_metadata['vote_count']>10].drop('vote_count', axis=1)

print('Shape Movie-Metadata:\t{}'.format(movie_metadata.shape))
movie_metadata.sample(5)

# %% [markdown]
# Around 21,000 entries in the movies metadata dataset

# %% [markdown]
# ## 3.2: Load User-Movie-Rating Dataset

# %%
# Dowload large file from the shared GDrive folder
# !pip install gdown
# !gdown "https://drive.google.com/uc?export=download&id=1z0O0fXuofdsbpL8fkCVgjeIwFP_LxGX2" -O data/

# %%
# Load single data-file
df_raw = pd.read_csv('./data/combined_data.csv.zip', 
                     header=None, 
                     names=['User', 'Rating', 'Date'], 
                     usecols=[0, 1, 2])

# Find empty rows to slice dataframe for each movie
tmp_movies = df_raw[df_raw['Rating'].isna()]['User'].reset_index()
movie_indices = [[index, int(movie[:-1])] for index, movie in tmp_movies.values]

# Shift the movie_indices by one to get start and endpoints of all movies
shifted_movie_indices = deque(movie_indices)
shifted_movie_indices.rotate(-1)

# Gather all dataframes
user_data = []

# Iterate over all movies
for [df_id_1, movie_id], [df_id_2, next_movie_id] in zip(movie_indices, shifted_movie_indices):
    
    # Check if it is the last movie in the file
    if df_id_1<df_id_2:
        tmp_df = df_raw.loc[df_id_1+1:df_id_2-1].copy()
    else:
        tmp_df = df_raw.loc[df_id_1+1:].copy()
        
    # Create movie_id column
    tmp_df['Movie'] = movie_id
    
    # Append dataframe to list
    user_data.append(tmp_df)

# Combine all dataframes
df = pd.concat(user_data)
del user_data, df_raw, tmp_movies, tmp_df, shifted_movie_indices, movie_indices, df_id_1, movie_id, df_id_2, next_movie_id
print('Shape User-Ratings:\t{}'.format(df.shape))
df.sample(10)

# %% [markdown]
# There are about 24 Million+ different rating records!

# %% [markdown]
# We have taken the data required for building the system and now let's do some EDA on the dataset to better understand our data

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# ## 4.1: When were the movies released?

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 6))

data = movie_titles['Year'].value_counts().sort_index()
x = data.index.map(int)
y = data.values

sns.barplot(x, y)
xmin, xmax = plt.xlim()
xtick_labels = [x[0]] + list(x[10:-10:10]) + [x[-1]]
plt.xticks(ticks=np.linspace(xmin, xmax, 10), labels=xtick_labels);

# %% [markdown]
# Many movies on Netflix have been released in this millennial. Whether Netflix prefers young movies or there are no old movies left can not be deduced from this plot.
# The decline for the rightmost point is probably caused by an incomplete last year.

# %% [markdown]
# ## Q 4.2: How are The Ratings Distributed?
#
# __Your Turn:__ Build the visualization for rating distributions similar to the previous plot.

# %% [markdown]
# Netflix movies rarely have a rating lower than three. Most ratings have between three and four stars.
# The distribution is probably biased, since only people liking the movies proceed to be customers and others presumably will leave the platform.

# %% [markdown]
# ## 4.3: Visualize the Distribution of Number of Movie Ratings
#
# This is to understand how many movies (y-axis) are receiving specific number of movie ratings (x-axis)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

data = df.groupby('Movie')['Rating'].count()
sns.distplot(data[data  < 10000], kde=False, ax=ax[0]);
sns.distplot(data[data  > 10000], kde=False, ax=ax[1]);

# %% [markdown]
# ## Q 4.4: Visualize the Distribution of Number of User Ratings
#
# This is to understand how many users (y-axis) are giving specific number of movie ratings (x-axis)
#
# __Your Turn:__ Try to find out an optimal threshold as in the previous example to split the data to form two understandable subplots!

# %% [markdown]
# The ratings per movie as well as the ratings per user both have nearly a perfect exponential decay. Only very few movies/users have many ratings.

# %% [markdown]
# # 5. Dimensionality Reduction & Filtering

# %% [markdown]
# ## Filter Sparse Movies And Users
#
# To reduce the dimensionality of the dataset I am filtering rarely rated movies and rarely rating users out.

# %%
# Filter sparse movies
min_movie_ratings = 1000
filter_movies = (df['Movie'].value_counts()>min_movie_ratings)
filter_movies = filter_movies[filter_movies].index.tolist()

# Filter sparse users
min_user_ratings = 200
filter_users = (df['User'].value_counts()>min_user_ratings)
filter_users = filter_users[filter_users].index.tolist()

# Actual filtering
df_filtered = df[(df['Movie'].isin(filter_movies)) & (df['User'].isin(filter_users))]
del filter_movies, filter_users, min_movie_ratings, min_user_ratings
print('Shape User-Ratings unfiltered:\t{}'.format(df.shape))
print('Shape User-Ratings filtered:\t{}'.format(df_filtered.shape))

# %% [markdown]
# After filtering sparse movies and users about 5.9M rating records are present.

# %% [markdown]
# # 6. Create Train and Test Datasets
#
# Do note this will be used for the statistical method based models and collaborative filtering.
#
# For content based filtering it is more of a model which recommends movies rather than predicting ratings and for the hybrid model we will need to recreate the train and test datasets later since we need to create a subset of movies-users-ratings which have movie text descriptions.

# %% [markdown]
# ## Create Train and Test datasets

# %%
# Shuffle DataFrame
df_filtered = df_filtered.drop('Date', axis=1).sample(frac=1).reset_index(drop=True)

# Testingsize
n = 100000

# Split train- & testset
df_train = df_filtered[:-n]
df_test = df_filtered[-n:]
df_train.shape, df_test.shape

# %% [markdown]
# The train set will be used to train all models and the test set ensures we can compare model performance on unseen data using the RMSE metric.

# %% [markdown]
# # 7. Transformation

# %% [markdown]
# ### Q 7.1: Transform The User-Movie-Ratings Data Frame to User-Movie Matrix

# %% [markdown]
# A large, sparse matrix will be created in this step. Each row will represent a user and its ratings and the columns are the movies.
#
# The movies already rated by users are the non-empty values in the matrix.
#
# Empty values are unrated movies and the main objective is to estimate the empty values to help our users.
#
#
# __Your turn:__ Create the User-Movie matrix leveraging the __`pivot_table()`__ function from pandas.
#
# Fill in the blanks in the code below by referencing the __`pivot_table()`__ function and invoking it on __`df_train`__. Feel free to check out the documentation.
#
# Remember, rows should be users, columns should be movies and the values in the matrix should be the movie ratings. All these should be available in the __`df_train`__ dataframe.

# %%
# Create a user-movie matrix with empty values
df_p = <YOUR CODE HERE>
print('Shape User-Movie-Matrix:\t{}'.format(df_p.shape))
df_p.head(10)

# %% [markdown]
# ## 8. Building Recommendation Systems

# %% [markdown]
# ## 8.1(a): Global Recommendation Systems (Mean Rating)
#
# Computing the mean rating for all movies creates a ranking. The recommendation will be the same for all users and can be used if there is no information on the user.
# Variations of this approach can be separate rankings for each country/year/gender/... and to use them individually to recommend movies/items to the user.
#
# It has to be noted that this approach is biased and favours movies with fewer ratings, since large numbers of ratings tend to be less extreme in its mean ratings.

# %% [markdown]
# ### Additional Hint
#
# Predict model performance: [mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)

# %%
# Compute mean rating for all movies
ratings_mean = df_p.mean(axis=0).sort_values(ascending=False).rename('Rating-Mean').to_frame()

# Compute rating frequencies for all movies
ratings_count = df_p.count(axis=0).rename('Rating-Freq').to_frame()

# Combine the aggregated dataframes
combined_df = ratings_mean.join(ratings_count).join(movie_titles)
combined_df.head(5)

# %%
# Join labels and predictions based on mean movie rating
predictions_df = df_test.set_index('Movie').join(ratings_mean)
predictions_df.head(5)

# %%
# Compute RMSE
y_true = predictions_df['Rating']
y_pred = predictions_df['Rating-Mean']

rmse = np.sqrt(mean_squared_error(y_true=y_true, y_pred=y_pred))
print("The RMSE Value for the Mean Rating Recommender:", rmse)

# %%
# View top ten rated movies
combined_df[['Name', 'Rating-Mean']].head(10)

# %% [markdown]
# ## Q 8.1(b): Global Recommendation Systems (Weighted Rating)
#
# To tackle the problem of the unstable mean with few ratings e.g. IDMb uses a weighted rating. Many good ratings outweigh few in this algorithm.
#
# ### Hint:
#
# Weighted Rating Formula
#
# weighted rating (𝑊𝑅)=(𝑣/(𝑣+𝑚))𝑅+(𝑚/(𝑣+𝑚))𝐶
#
# where:
#
# *𝑅* = average for the movie (mean) = (Rating)
#
# *𝑣* = number of votes for the movie = (votes)
#
# *𝑚* = minimum votes required
#
# *𝐶* = the mean vote across the whole report
#
# __Your Turn:__ Fill in the necessary code snippets below to build and test the model

# %%
# Number of minimum votes to be considered
m = 1000

# Mean rating for all movies
C = df_p.stack().mean()

# Mean rating for all movies separately
R = df_p.mean(axis=0).values

# Rating freqency for all movies separately
v = df_p.count().values

# %%
# Weighted formula to compute the weighted rating
weighted_score = <YOUR CODE HERE>

# %%
# convert weighted_score into a dataframe
weighted_mean = <YOUR CODE HERE>

# Combine the aggregated dataframes (wighted_mean & movie_titles)
combined_df = <YOUR CODE HERE>
combined_df.head(5)

# %%
# Join labels and predictions based on mean movie rating
predictions_df = <YOUR CODE HERE>
predictions_df.head(5)

# %%
# Compute RMSE
y_true = <YOUR CODE HERE>
y_pred = <YOUR CODE HERE>

rmse = <YOUR CODE HERE>
print("The RMSE Value for the Weighted-Mean Rating Recommender:", rmse)

# %%
# View top ten rated movies
<YOUR CODE HERE>

# %% [markdown]
# The variable "m" can be seen as regularizing parameter. Changing it determines how much weight is put onto the movies with many ratings.
# Even if there is a better ranking the RMSE decreased slightly. There is a trade-off between interpretability and predictive power.

# %% [markdown]
# ## 8.2: Content Based Recommendation Systems
#
#
# The Content-Based Recommender relies on the similarity of the items being recommended. The basic idea is that if you like an item, then you will also like a “similar” item. It generally works well when it’s easy to determine the context/properties of each item. If there is no historical data for a user or there is reliable metadata for each movie, it can be useful to compare the metadata of the movies to find similar ones.
#
# ![](./images/Content-based.png)

# %% [markdown]
# ### Cosine TFIDF Movie Description Similarity

# %% [markdown]
# #### TF-IDF
#
# This is a text vectorization technique which is used to determine the relative importance of a document / article / news item / movie etc.
#
# TF is simply the frequency of a word in a document.
#
# IDF is the inverse of the document frequency among the whole corpus of documents.
#
# TF-IDF is used mainly because of two reasons: Suppose we search for “the results of latest European Socccer games” on Google. It is certain that “the” will occur more frequently than “soccer games” but the relative importance of soccer games is higher than the search query point of view.
#
# In such cases, TF-IDF weighting negates the effect of high frequency words in determining the importance of an item (document).
#
# ![](./images/TF-IDF-FORMULA.png)

# %% [markdown]
# #### Cosine Similarity
# After calculating TF-IDF scores, how do we determine which items are closer to each other, rather closer to the user profile? This is accomplished using the Vector Space Model which computes the proximity based on the angle between the vectors.
#
# Consider the following example
#
# ![](./images/vector-space-model.png)
#
# Sentence 2 is more likely to be using Term 2 than using Term 1. Vice-versa for Sentence 1.
#
# The method of calculating this relative measure is calculated by taking the cosine of the angle between the sentences and the terms.
#
# The ultimate reason behind using cosine is that the value of cosine will increase with decreasing value of the angle between which signifies more similarity.
#
# The vectors are length normalized after which they become vectors of length 1 and then the cosine calculation is simply the sum-product of vectors.

# %% [markdown]
# In this approch we will use the movie description to create a TFIDF-matrix, which counts and weights words in all descriptions, and compute a cosine similarity between all of those sparse text-vectors. This can easily be extended to more or different features if you like.
# It is impossible for this model to compute a RMSE score, since the model does not recommend the movies directly.
# In this way it is possible to find movies closly related to each other.
#
# This approach of content based filtering can be extendend to increase the model performance by adding some more features like genres, cast, crew etc.

# %%
# view sample movie descriptions
movie_metadata['overview'].head(5)

# %%
# Create tf-idf matrix for text comparison
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movie_metadata['overview'])

# %%
# Compute cosine similarity between all movie-descriptions
similarity = cosine_similarity(tfidf_matrix)
similarity_df = pd.DataFrame(similarity, 
                             index=movie_metadata.index.values, 
                             columns=movie_metadata.index.values)
similarity_df.head(10)

# %%
# movie list 
movie_list = similarity_df.columns.values


# sample movie
movie = 'Batman Begins'

# top recommendation movie count
top_n = 10

# get movie similarity records
movie_sim = similarity_df[similarity_df.index == movie].values[0]

# get movies sorted by similarity
sorted_movie_ids = np.argsort(movie_sim)[::-1]

# get recommended movie names
recommended_movies = movie_list[sorted_movie_ids[1:top_n+1]]

print('\n\nTop Recommended Movies for:', movie, 'are:-\n', recommended_movies)

# %% [markdown]
# __Your turn:__ Create a function as defined below, __`content_movie_recommender()`__ which can take in sample movie names and print a list of top N recommended movies

# %%
def content_movie_recommender(input_movie, similarity_database=similarity_df, movie_database_list=movie_list, top_n=10):
    
    <YOUR CODE HERE>

# %% [markdown]
# __Your turn:__ Test your function below on the given sample movies

# %%
sample_movies = ['Captain America', 'The Terminator', 'The Exorcist', 
                 'The Hunger Games: Mockingjay - Part 1', 'The Blair Witch Project']
                 
<YOUR CODE HERE>

# %% [markdown]
# ## 8.3: Collaborative filtering Recommendation Systems

# %% [markdown]
# ### Collaborative Filtering
# Primarily recommends content to you based on inputs or actions from other people(say your friends).
# ![collaborative filtering](./images/collaborative-filtering.png)

# %% [markdown]
# ### What is the intuition behind this?
#
# *   **Personal tastes are correlated**
#
#
#         1.   If Alice and Bob both like X and Alice likes Y then Bob is more likely to like Y
#         2.   especially (perhaps) if Bob knows Alice

# %% [markdown]
# Types of Collaborative Filtering:
#
#
# 1.   Neighborhood methods
# 2.   Matrix Factorization (Latent Factor) methods

# %% [markdown]
# Assume you dont have users. Rather you have users' characterisics and properties(as shown in image).![Latent Factor method](https://miro.medium.com/max/876/1*AQEx38Wdo5H0WTSjRfAWtA.png)
#
# For example, a person who is brave-hearted is more likely to be interested in dark, horrific movies rather than someone who is soft and compassionate.
# * ^This is just an example(not in any literal sense)

# %% [markdown]
# So, once you have the properties and characteristics of each user, we call them as lower-dimensional features of the users. Similarly, we can have lower-dimensional features for movies(say its 10% action, 20% romance ...)
#
# With these features, we represent users and movies in a low dimensional space describing their properties. **This is called as the latent space.**
#
# We then recommend a movie based on its proximity to the user in the latent space.

# %% [markdown]
# ### The problem:
#
# The problem we try to address here is the rating prediction problem.
# Say, we try to guess how much Alice would rate a movie and suggest those movies that we think Alice will rate higher.

# %% [markdown]
# ### Interesting...But, how do we predict how much Alice would rate a movie?
#
#  The data we have is a rating history: ratings of users for items in the interval [1,5]. We can put all this data into a sparse matrix called R:
#
#  $R =
#  \begin{pmatrix}
#   3 & ? &? \\
#   ? & 4 & 5 \\
#   ? & ? & 2 \\
#   2 & 3 & ?
#  \end{pmatrix}
#  \begin{matrix}
#   Alice \\
#   Bob \\
#   Chand \\
#   Deb
#  \end{matrix}
#  $
#
#  Each row of the matrix corresponds to a given user, and each column corresponds to a given item. For instance here, Alice has rated the first movie with a rating of 3, and Chand has rated the third item with a rating of 2.
#
#  The matrix R is sparse (more than 99% of the entries are missing), and our goal is to predict the missing entries, i.e. predict the ?.

# %% [markdown]
# ### Anatomy of the Rating matrix: LATENT SPACE
# Before predicting ratings, lets step back and understand the latent space more! \\
#  In this Rating matrix, Rows represent Users and Columns represent Movies.
#  $R =
#   \begin{pmatrix}
#   --Alice-- \\
#   --Bob-- \\
#   --Chand-- \\
#   --Deb--
#  \end{pmatrix}
#  $
#
#  In latent space(low dimensional features - fanatics), for instance, Alice could be defined as a little bit of an action fan, a little bit of a comedy fan, a lot of a romance fan, etc. As for Bob, he could be more keen on action movies:
#
# ```
# Alice = 10% Action fan + 10% Comedy fan + 50% Romance fan + ⋯ \\
# Bob = 50% Action fan + 30% Comedy fan + 10% Romance fan + ⋯ \\
# : \\
# Zoe = ⋯
# ```
#
# What would happen if we transposed our rating matrix? Instead of having users in the rows, we would now have movies, defined as their ratings.
#
# $
# R ^ T =
#   \begin{pmatrix}
#   --Avengers-- \\
#   --Matrix-- \\
#   --Inception-- \\
#   --Sherlock--
#  \end{pmatrix}
# $
#
# In the latent space, we will associate a semantic meaning behind each of the  movies, and these semantic meanings(say movie characteristics) can build back all of our original movies.

# %% [markdown]
# ### EXAMPLE
# In the below example, we convert users and movies to vectors(embeddings) and do dot-product to predict R
#
# user vector - U \\
# movies vector - V \\
# $
# R = U.V
# $

# %% [markdown]
# ### Additional hints:
#
# use dataframe map - [map](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html)
#
# Create tensor - [Input](https://www.tensorflow.org/api_docs/python/tf/keras/Input#view-aliases)
#
# Create Embedding - [Embedding](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding)
#
# Dot product - [Dot](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dot)
#
# Fit model :
# [fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit)
#
# Measure Performance: [mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)

# %% [markdown]
# ### Q8.3: Building a Deep Learning Matrix Factorization based Collaborative Filtering Recommendation System
#
# __Your Turn:__ Fill in the necessary blank code snippets in the following sections to train your own DL collaborative  filtering system
#
# #### Create Configuration Parameters

# %%
# Create user and movie-id mapping to convert to numbers
user_id_mapping = {id:i for i, id in enumerate(df_filtered['User'].unique())}
movie_id_mapping = {id:i for i, id in enumerate(df_filtered['Movie'].unique())}

# %%
# use dataframe map function to map users & movies to mapped ids based on above mapping
train_user_data = df_train['User'].map(user_id_mapping)
train_movie_data = df_train['Movie'].map(movie_id_mapping)

# %%
# do the same for test data
test_user_data = <YOUR CODE HERE>
test_movie_data = <YOUR CODE HERE>

# %%
# Get input variable-sizes
users = len(user_id_mapping)
movies = len(movie_id_mapping)
embedding_size = 100

# %% [markdown]
# #### Construct Deep Learning Model Architecture

# %%
# use Input() to create tensors for - 'user' and 'movie'
user_id_input = Input(shape=(1,), name='user')
movie_id_input = <YOUR CODE HERE>

# %%
# Create embedding layer for users 
user_embedding = Embedding(output_dim=embedding_size, 
                           input_dim=users,
                           input_length=1, 
                           name='user_embedding')(user_id_input)

# create embedding layer for movies just like users
movie_embedding = <YOUR CODE HERE>

# %%
# Reshape the embedding layers
user_vector = Reshape([embedding_size])(user_embedding)
movie_vector = <YOUR CODE HERE>

# %%
# Compute dot-product of reshaped embedding layers as prediction
y = Dot(1, normalize=False)([user_vector, movie_vector])

# %%
# Setup model
model = Model(inputs=[user_id_input, movie_id_input], outputs=y)
model.compile(loss='mse', optimizer='adam')
model.summary()

# %% [markdown]
# #### Train and Test the Model

# %%
# Fit model
X = [train_user_data, train_movie_data]
y = df_train['Rating']

batch_size = 1024
epochs = 5
validation_split = 0.1

model.fit(X, y,
          batch_size=batch_size, 
          epochs=epochs,
          validation_split=validation_split,
          shuffle=True,
          verbose=1)

# %%
# Test model by making predictions on test data
y_pred = model.predict([test_user_data, test_movie_data]).ravel()
# clip upper and lower ratings
y_pred = list(map(lambda x: 1.0 if x < 1 else 5.0 if x > 5.0 else x, y_pred))
# get true labels
y_true = df_test['Rating'].values

#  Compute RMSE
rmse = np.sqrt(mean_squared_error(y_pred=y_pred, y_true=y_true))
print('\n\nTesting Result With DL Matrix-Factorization: {:.4f} RMSE'.format(rmse))

# %%
## Let's see how our collaborative model performs by seeing the predicted and actual rating for the given user and movie pair
results_df = pd.DataFrame({
    'User ID': test_user_data.values,
    'Movie ID': test_movie_data.values,
    'Movie Name': [movie_titles['Name'].iloc[item] for item in test_movie_data],
    'Predicted Rating': np.round(y_pred, 1),
    'Actual Rating': y_true
})

results_df.head(20)

# %% [markdown]
# ## 8.4: Hybrid Recommendation System (Content & Collaborative)
#
# One advantage of deep learning models is, that movie-metadata can easily be added to the model.
# We will tf-idf transform the short description of all movies to a sparse vector. The model will learn to reduce the dimensionality of this vector and how to combine metadata with the embedding of the user-id and the movie-id. In this way we can add any additional metadata to our own recommender.
# These kind of hybrid systems can learn how to reduce the impact of the cold start problem.
#
# Deep learning models require lots of data to train and predict. To provide our model with more data, we will include the movie metadata as well. We will do the following:
#
#
# *   Use movie metadata to combine with user and movie matrices in order to get more data
# *   Use tf-idf transform to vectorize movie metadata (Sparse Layer)
# *   Create an embedding of the metadata 512 -> 256
# *   Combine all embeddings for movie tf-idf vectors, user and ratings to arrive at a common embedding space (256 sized embeddings per entity)
# *   Use the embeddings to train the model and get predictions on the test data

# %% [markdown]
# ### Additional Hints:
#
# Dense layer setup :
# [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense#example_2)
#
# Create model using tf.keras API :
# [Model](https://www.tensorflow.org/api_docs/python/tf/keras/Model#used-in-the-notebooks)
#
# Compile model using : [Compile](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile)
#
# Fit model :
# [fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit)
#
# Predict accuracy: [mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)

# %% [markdown]
# ### Q8.3: Building a Deep Learning Hybrid Recommendation System
#
# We will be building the following hybrid deep learning recommendation model as scene in the following schematic.
#
# ![](./images/hybrid-dl-model.png)
#
# __Your Turn:__ Fill in the necessary blank code snippets in the following sections to train your own DL hybrid recommendation system
#
# #### Create Configuration Parameters

# %%
# ceate a copy of the filtered data frame
df_filtered_cp = df_filtered.copy(deep=True)

# %%
# Create user- & movie-id mapping
user_id_mapping = {id:i for i, id in enumerate(df_filtered_cp['User'].unique())}
movie_id_mapping = {id:i for i, id in enumerate(df_filtered_cp['Movie'].unique())}

# %%
# use dataframe map function to map users & movies to mapped ids based on above mapping
df_filtered_cp['User'] = df_filtered_cp['User'].map(user_id_mapping)
df_filtered_cp['Movie'] = <YOUR CODE HERE>

# %% [markdown]
# #### Create Movie Description Dataset (Content)

# %%
# Preprocess metadata
tmp_metadata = movie_metadata.copy()
tmp_metadata.index = tmp_metadata.index.str.lower()

# Preprocess titles
tmp_titles = movie_titles.drop('Year', axis=1).copy()
tmp_titles = tmp_titles.reset_index().set_index('Name')
tmp_titles.index = tmp_titles.index.str.lower()

# Combine titles and metadata
df_id_descriptions = tmp_titles.join(tmp_metadata).dropna().set_index('Id')
df_id_descriptions['overview'] = df_id_descriptions['overview'].str.lower()
#del tmp_metadata,tmp_titles
print('Movie Description DF Shape:', df_id_descriptions.shape)
df_id_descriptions.tail()

# %% [markdown]
# #### Create User-Rating Filtered Dataset (Collaborative)
#
# Here we filter out movie-user-ratings where movies don't have descriptions (content)

# %%
df_hybrid = (df_filtered_cp.set_index('Movie')
               .join(df_id_descriptions)
               .dropna()
               .drop('overview', axis=1)
               .reset_index().rename({'index':'Movie'}, 
                                      axis=1))
print('Movie-User-Rating DF Shape:', df_hybrid.shape)
df_hybrid.head()

# %%
# Split train- & testset
n = 300000
df_hybrid = df_hybrid.sample(frac=1).reset_index(drop=True)
df_hybrid_train = df_hybrid[:-n]
df_hybrid_test = df_hybrid[-n:]
df_hybrid_train.shape, df_hybrid_test.shape

# %% [markdown]
# #### Generate TFIDF Vectors for Train and Test Datasets (Movie Descriptions)

# %%
# Create tf-idf matrix for movie description vectors - HINT: check the overview column of df_id_description
tfidf = <YOUR CODE HERE>
tfidf_hybrid = tfidf.fit_transform(<YOUR CODE HERE>)

# %%
# Get mapping from movie-ids to indices in tfidf-matrix
movie_idx_mapping = {id:i for i, id in enumerate(df_id_descriptions.index)}

# %%
# get train data tfidf vectors
train_tfidf = []

# Iterate over all movie-ids and save the tfidf-vectors (sparse format for memory efficiency)
for idx in tqdm(df_hybrid_train['Movie'].values):
    index = movie_idx_mapping[idx]
    train_tfidf.append(tfidf_hybrid[index])

len(train_tfidf)

# %%
# get test data tfidf vectors
test_tfidf = []

# Iterate over all movie-ids and save the tfidf-vectors (sparse format for memory efficiency)
<YOUR CODE HERE>

len(test_tfidf)

# %%
# Stack the sparse matrices
train_tfidf = vstack(train_tfidf)
test_tfidf = <YOUR CODE HERE>

train_tfidf.shape, test_tfidf.shape

# %%
type(train_tfidf)

# %% [markdown]
# This shows we are using sparse matrices to represent the vectors as dense vectors would typically give a out of memory error!

# %% [markdown]
# #### Construct Deep Learning Model Architecture

# %%
# setup NN parameters
user_embed_dim = 256
movie_embed_dim = 256
userid_input_shape = 1
movieid_input_shape = 1
tfidf_input_shape = tfidf_hybrid.shape[1]

# %%
# Create the input layers

# user and movie input layers
user_id_input = Input(shape=(userid_input_shape,), name='user')
movie_id_input = <YOUR CODE HERE>

# tfidf input layer
tfidf_input = Input(shape=(tfidf_input_shape,), name='tfidf', sparse=True)

# %%
# Create embeddings layers for users and movies

# user embedding
user_embedding = Embedding(output_dim=user_embed_dim,
                           input_dim=len(user_id_mapping),
                           input_length=userid_input_shape,
                           name='user_embedding')(user_id_input)

# movie embedding
movie_embedding = <YOUR CODE HERE>

# %%
# Dimensionality reduction with Dense layers
tfidf_vectors = Dense(512, activation='relu')(tfidf_input)
tfidf_vectors = Dense(256, activation='relu')(tfidf_vectors)

# %%
# Reshape both user and movie embedding layers
user_vectors = Reshape([user_embed_dim])(user_embedding)
movie_vectors = <YOUR CODE HERE>

# %%
# Concatenate all layers into one 
hybrid_layer = Concatenate()([user_vectors, movie_vectors, tfidf_vectors])

# %%
# add in dense and output layers
dense = Dense(512, activation='relu')(hybrid_layer)
dense = Dropout(0.2)(dense)
output = Dense(1)(dense)

# %%
# create and view model summary
model = Model(inputs=[user_id_input, movie_id_input, tfidf_input], outputs=output)
model.compile(loss='mse', optimizer='adam')
model.summary()

# %% [markdown]
# #### Train and Test the Model

# %%
# fit the model
batch_size=1024
epochs=10
X = [df_hybrid_train['User'], df_hybrid_train['Movie'], train_tfidf]
y = df_hybrid_train['Rating']
model.fit(X, y,
          batch_size=batch_size, 
          epochs=epochs, ## Change the epochs to find better improved model.
          validation_split=0.1,
          shuffle=True)

# %%
# create test input data and true outputs
X_test = [df_hybrid_test['User'], df_hybrid_test['Movie'], test_tfidf]
y_true = df_hybrid_test['Rating'].values 

# Test model by making predictions on test data
y_pred = model.predict(X_test).ravel()
# clip upper and lower ratings
y_pred = list(map(lambda x: 1.0 if x < 1 else 5.0 if x > 5.0 else x, y_pred))

#  Compute RMSE
rmse = np.sqrt(mean_squared_error(y_pred=y_pred, y_true=y_true))
print('\n\nTesting Result With DL Hybrid Recommender: {:.4f} RMSE'.format(rmse))

# %%
## Let's see how our collaborative model performs by seeing the predicted and actual rating for the given user and movie pair
results_df = pd.DataFrame({
    'User ID': df_hybrid_test['User'].values,
    'Movie ID': df_hybrid_test['Movie'].values,
    'Movie Name': [movie_titles['Name'].iloc[item] for item in df_hybrid_test['Movie']],
    'Predicted Rating': np.round(y_pred, 1),
    'Actual Rating': y_true
})

results_df.head(20)
